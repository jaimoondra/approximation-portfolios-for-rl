# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import pandas as pd
from src.p_mean import generalized_p_mean, generate_p_grid, get_optimum_vector, get_optimum_value
from src.portfolio import portfolio_with_line_search, budget_portfolio_with_suboptimalities, compute_portfolio_worst_approx_ratio, portfolio_of_random_norms, portfolio_of_random_policies, Policy, Portfolio, portfolio_with_gpi

plt.rcParams['figure.dpi'] = 200

# %% [markdown]
# ## Load data

# %%
df = pd.read_csv('../../data/sclm_real_world/policy_rewards.csv')

# Remove rows with zero scores
for id in df['Key']:
    if df.loc[df['Key'] == id, 'Score for reward function 0'].values[0] == 0.0:
        # remove the row
        df = df[df['Key'] != id]

df
# Out:
#                                             Key                      Category  \
# 0             Enrollment gestational age (0-10)    Enrollment gestational age
# 1            Enrollment gestational age (11-20)    Enrollment gestational age
# 4              Enrollment delivery status (0-0)    Enrollment delivery status
# 5              Enrollment delivery status (1-1)    Enrollment delivery status
# 7       Gravidity (number of pregnancies) (1-1)         Number of pregnancies
# 8       Gravidity (number of pregnancies) (2-4)         Number of pregnancies
# 9      Gravidity (number of pregnancies) (5-10)         Number of pregnancies
# 10  Parity (number of viable pregnancies) (0-0)  Number of viable pregnancies
# 11  Parity (number of viable pregnancies) (1-1)  Number of viable pregnancies
# 12  Parity (number of viable pregnancies) (2-2)  Number of viable pregnancies
# 13  Parity (number of viable pregnancies) (3-3)  Number of viable pregnancies
# 14  Parity (number of viable pregnancies) (4-4)  Number of viable pregnancies
# 15  Parity (number of viable pregnancies) (5-5)  Number of viable pregnancies
# 16                     Still births count (0-0)            Still births count
# 17                     Still births count (1-1)            Still births count
# 22                      Live births count (0-1)             Live births count
# 23                      Live births count (2-4)             Live births count
# 24                     Live births count (5-10)             Live births count
# 25                Days to the first call (0-30)        Days to the first call
# 26              Days to the first call (31-100)        Days to the first call
# 28                                   Ages 10-20                           Age
# 29                                   Ages 21-30                           Age
# 30                                   Ages 31-40                           Age
# 31                                   Ages 41-50                           Age
# 32                                   Ages 51-60                           Age
# 33              Income bracket 1 (e.g., 0-5000)                Income bracket
# 34          Income bracket 2 (e.g., 5001-10000)                Income bracket
# 35         Income bracket 3 (e.g., 10001-15000)                Income bracket
# 36         Income bracket 4 (e.g., 15001-20000)                Income bracket
# 37         Income bracket 5 (e.g., 20001-25000)                Income bracket
# 38         Income bracket 6 (e.g., 25001-30000)                Income bracket
# 39        Income bracket 7 (e.g., 30000-999999)                Income bracket
# 40                               8:30am-10:30am                  Time of call
# 41                              10:30am-12:30pm                  Time of call
# 42                               12:30pm-3:30pm                  Time of call
# 43                                3:30pm-5:30pm                  Time of call
# 44                                5:30pm-7:30pm                  Time of call
# 45                                7:30pm-9:30pm                  Time of call
# 46                                   Illiterate               Education level
# 47                        1-5th Grade Completed               Education level
# 48                        6-9th Grade Completed               Education level
# 49                            10th Grade Passed               Education level
# 50                            12th Grade Passed               Education level
# 51                                     Graduate               Education level
# 52                                Post graduate               Education level
# 53                                 Speaks Hindi                      Language
# 54                               Speaks Marathi                      Language
# 56                               Speaks Kannada                      Language
# 57                          Phone owner - Woman                   Phone owner
# 58                        Phone owner - Husband                   Phone owner
# 59                         Phone owner - Family                   Phone owner
# 60                                          NGO                        Source
# 61                                       ARMMAN                        Source
#
#     Score for reward function 0  Score for reward function 1  \
# 0                        332.09                       313.49
# 1                        209.38                       184.67
# 4                       1005.38                       938.73
# 5                        173.24                       164.36
# 7                        621.27                       594.71
# 8                        537.24                       490.16
# 9                          6.53                         5.98
# 10                       583.02                       556.22
# 11                       391.64                       350.80
# 12                       162.69                       158.24
# 13                        33.36                        30.13
# 14                         6.73                         6.40
# 15                         1.18                         1.29
# 16                      1151.51                      1078.62
# 17                        21.40                        17.76
# 22                       993.42                       924.56
# 23                       184.44                       177.58
# 24                         0.76                         0.96
# 25                       437.80                       390.71
# 26                        11.80                        10.49
# 28                       158.78                       150.69
# 29                       573.04                       535.33
# 30                       360.53                       333.22
# 31                        71.31                        69.42
# 32                        14.96                        14.42
# 33                       188.09                       253.98
# 34                       483.62                       399.22
# 35                       340.13                       303.29
# 36                       109.89                        92.47
# 37                        43.29                        40.42
# 38                         6.00                         5.71
# 39                         7.60                         8.00
# 40                       220.42                       267.44
# 41                        96.47                        86.09
# 42                       346.64                       302.00
# 43                       141.38                       123.78
# 44                       133.38                       115.29
# 45                       240.33                       208.49
# 46                        66.49                        91.18
# 47                       213.98                       199.18
# 48                       368.60                       349.33
# 49                       264.64                       237.04
# 50                       151.11                       128.33
# 51                        24.82                        21.20
# 52                        88.98                        76.82
# 53                       608.96                       575.87
# 54                       566.07                       522.67
# 56                         3.60                         4.56
# 57                      1044.27                       986.67
# 58                       120.29                       105.18
# 59                        14.07                        11.24
# 60                       887.80                       840.60
# 61                       290.82                       262.49
#
#     Score for reward function 2  Score for reward function 3  \
# 0                        302.93                       302.33
# 1                        184.76                       192.60
# 4                        921.09                       933.60
# 5                        162.13                       159.09
# 7                        578.18                       568.93
# 8                        486.64                       501.07
# 9                          5.53                         6.56
# 10                       542.22                       535.96
# 11                       345.49                       354.80
# 12                       158.71                       163.24
# 13                        30.38                        30.49
# 14                         5.04                         5.64
# 15                         1.38                         2.56
# 16                      1058.38                      1066.96
# 17                        17.80                        18.38
# 22                       905.13                       908.76
# 23                       177.16                       182.29
# 24                         0.93                         1.64
# 25                       391.22                       398.13
# 26                        10.58                         8.91
# 28                       147.49                       157.89
# 29                       523.31                       527.07
# 30                       330.16                       324.78
# 31                        68.36                        67.00
# 32                        13.91                        15.96
# 33                       221.71                       167.33
# 34                       410.82                       452.87
# 35                       303.02                       329.71
# 36                        93.67                        90.09
# 37                        40.51                        39.16
# 38                         5.98                         6.22
# 39                         7.51                         7.31
# 40                       239.78                       202.33
# 41                        86.00                        89.40
# 42                       306.31                       324.53
# 43                       125.13                       129.36
# 44                       113.02                       122.71
# 45                       212.98                       224.36
# 46                        77.76                        84.78
# 47                       202.98                       281.67
# 48                       339.29                       304.78
# 49                       235.27                       211.09
# 50                       130.29                       125.38
# 51                        20.49                        20.64
# 52                        77.16                        64.36
# 53                       569.73                       588.47
# 54                       509.69                       499.49
# 56                         3.80                         4.73
# 57                       965.67                       961.58
# 58                       106.91                       118.51
# 59                        10.64                        12.60
# 60                       822.02                       812.33
# 61                       261.20                       280.36
#
#     Score for reward function 4  Score for reward function 5  \
# 0                        320.29                       329.22
# 1                        196.80                       206.78
# 4                        966.87                       993.36
# 5                        171.51                       174.04
# 7                        595.31                       612.62
# 8                        519.87                       534.76
# 9                          7.47                         6.29
# 10                       559.20                       574.58
# 11                       372.31                       392.24
# 12                       167.00                       160.53
# 13                        31.42                        32.36
# 14                         6.73                         6.38
# 15                         1.71                         1.31
# 16                      1111.73                      1140.36
# 17                        20.60                        21.31
# 22                       949.80                       985.53
# 23                       187.44                       181.07
# 24                         1.13                         0.80
# 25                       416.00                       438.76
# 26                        12.78                        12.13
# 28                       159.96                       157.98
# 29                       548.16                       561.82
# 30                       344.51                       358.22
# 31                        70.20                        73.38
# 32                        15.56                        16.00
# 33                       184.13                       147.67
# 34                       479.82                       497.36
# 35                       335.02                       350.89
# 36                        87.22                       111.40
# 37                        38.53                        44.96
# 38                         5.93                         6.18
# 39                         7.71                         8.96
# 40                       221.13                       188.09
# 41                        90.58                        99.47
# 42                       327.31                       353.40
# 43                       132.76                       145.09
# 44                       128.71                       135.93
# 45                       237.89                       245.42
# 46                        74.87                        58.11
# 47                       234.84                       214.20
# 48                       412.62                       365.78
# 49                       208.80                       262.24
# 50                       124.04                       155.07
# 51                        19.27                        25.96
# 52                        63.93                        86.04
# 53                       592.22                       609.22
# 54                       542.13                       554.47
# 56                         4.02                         3.71
# 57                      1005.53                      1031.24
# 58                       121.56                       122.07
# 59                        11.29                        14.09
# 60                       862.31                       871.42
# 61                       276.07                       295.98
#
#     Score for reward function 6  Score for reward function 7  ...  \
# 0                        313.49                       330.82  ...
# 1                        184.67                       210.00  ...
# 4                        938.73                      1001.02  ...
# 5                        164.36                       173.98  ...
# 7                        594.71                       618.62  ...
# 8                        490.16                       536.11  ...
# 9                          5.98                         6.58  ...
# 10                       556.22                       580.80  ...
# 11                       350.80                       391.02  ...
# 12                       158.24                       161.84  ...
# 13                        30.13                        33.27  ...
# 14                         6.40                         6.93  ...
# 15                         1.29                         1.13  ...
# 16                      1078.62                      1147.84  ...
# 17                        17.76                        21.51  ...
# 22                       924.56                       990.20  ...
# 23                       177.58                       184.04  ...
# 24                         0.96                         0.76  ...
# 25                       390.71                       436.16  ...
# 26                        10.49                        11.96  ...
# 28                       150.69                       158.49  ...
# 29                       535.33                       570.51  ...
# 30                       333.22                       359.78  ...
# 31                        69.42                        71.09  ...
# 32                        14.42                        15.13  ...
# 33                       253.98                       186.02  ...
# 34                       399.22                       482.91  ...
# 35                       303.29                       340.71  ...
# 36                        92.47                       108.89  ...
# 37                        40.42                        43.11  ...
# 38                         5.71                         5.84  ...
# 39                         8.00                         7.51  ...
# 40                       267.44                       218.36  ...
# 41                        86.09                        95.67  ...
# 42                       302.00                       346.18  ...
# 43                       123.78                       141.36  ...
# 44                       115.29                       133.80  ...
# 45                       208.49                       239.64  ...
# 46                        91.18                        66.31  ...
# 47                       199.18                       214.24  ...
# 48                       349.33                       368.20  ...
# 49                       237.04                       262.76  ...
# 50                       128.33                       149.82  ...
# 51                        21.20                        24.93  ...
# 52                        76.82                        88.73  ...
# 53                       575.87                       608.33  ...
# 54                       522.67                       563.13  ...
# 56                         4.56                         3.53  ...
# 57                       986.67                      1041.38  ...
# 58                       105.18                       119.64  ...
# 59                        11.24                        13.98  ...
# 60                       840.60                       885.87  ...
# 61                       262.49                       289.13  ...
#
#     Score for reward function 275  Score for reward function 276  \
# 0                          327.80                         331.80
# 1                          201.87                         207.78
# 4                          994.33                        1001.20
# 5                          173.58                         171.09
# 7                          616.89                         617.73
# 8                          528.87                         533.87
# 9                            7.33                           6.22
# 10                         580.27                         581.91
# 11                         384.69                         383.38
# 12                         163.51                         167.33
# 13                          31.16                          31.87
# 14                           6.84                           6.38
# 15                           1.44                           1.42
# 16                        1140.53                        1145.49
# 17                          20.93                          20.91
# 22                         985.40                         984.04
# 23                         181.47                         187.33
# 24                           1.04                           0.91
# 25                         424.76                         431.73
# 26                          12.36                          12.40
# 28                         162.64                         157.33
# 29                         567.89                         567.60
# 30                         351.11                         357.62
# 31                          71.36                          73.44
# 32                          14.91                          16.29
# 33                         186.56                         184.58
# 34                         479.29                         479.38
# 35                         337.80                         341.33
# 36                         107.53                         108.16
# 37                          42.47                          43.69
# 38                           6.24                           6.24
# 39                           8.02                           8.91
# 40                         222.11                         214.60
# 41                          94.31                          97.18
# 42                         341.60                         347.44
# 43                         135.16                         141.56
# 44                         132.44                         129.51
# 45                         242.29                         242.00
# 46                          67.20                          67.22
# 47                         226.53                         210.62
# 48                         390.98                         373.02
# 49                         275.36                         259.13
# 50                         123.67                         149.96
# 51                          20.33                          25.31
# 52                          63.84                          87.02
# 53                         601.60                         612.58
# 54                         562.13                         555.44
# 56                           4.18                           4.27
# 57                        1031.27                        1040.16
# 58                         122.87                         119.49
# 59                          13.78                          12.64
# 60                         883.16                         878.24
# 61                         284.76                         294.04
#
#     Score for reward function 277  Score for reward function 278  \
# 0                          302.84                         299.87
# 1                          190.13                         184.29
# 4                          930.84                         908.40
# 5                          160.42                         161.49
# 7                          567.36                         563.64
# 8                          501.38                         487.58
# 9                            6.78                           5.11
# 10                         532.31                         527.60
# 11                         360.62                         355.31
# 12                         158.53                         152.40
# 13                          31.02                          27.71
# 14                           6.47                           5.62
# 15                           2.31                           1.24
# 16                        1063.42                        1046.00
# 17                          20.49                          17.38
# 22                         911.36                         900.71
# 23                         178.42                         168.44
# 24                           1.49                           0.73
# 25                         395.02                         398.22
# 26                           9.27                           9.78
# 28                         157.11                         145.96
# 29                         528.07                         520.00
# 30                         323.31                         324.87
# 31                          67.33                          65.64
# 32                          15.44                          13.42
# 33                         164.47                         163.18
# 34                         448.76                         432.20
# 35                         322.27                         320.93
# 36                         101.31                          97.62
# 37                          40.87                          41.82
# 38                           5.98                           6.51
# 39                           7.62                           7.62
# 40                         198.07                         191.44
# 41                          90.64                          90.13
# 42                         329.02                         319.07
# 43                         128.80                         127.80
# 44                         121.29                         120.11
# 45                         223.44                         221.33
# 46                          85.53                          63.11
# 47                         283.38                         198.18
# 48                         302.02                         335.76
# 49                         210.31                         238.11
# 50                         124.91                         137.47
# 51                          21.20                          22.87
# 52                          63.91                          74.40
# 53                         587.27                         563.49
# 54                         498.98                         502.47
# 56                           5.02                           3.93
# 57                         960.24                         945.38
# 58                         117.11                         112.40
# 59                          13.91                          12.11
# 60                         812.24                         800.71
# 61                         279.02                         269.18
#
#     Score for reward function 279  Score for reward function 280  \
# 0                          321.11                         299.87
# 1                          192.09                         184.29
# 4                          951.93                         908.40
# 5                          165.82                         161.49
# 7                          586.22                         563.64
# 8                          511.40                         487.58
# 9                            6.42                           5.11
# 10                         548.42                         527.60
# 11                         371.47                         355.31
# 12                         159.36                         152.40
# 13                          31.00                          27.71
# 14                           6.00                           5.62
# 15                           1.51                           1.24
# 16                        1090.49                        1046.00
# 17                          20.42                          17.38
# 22                         938.91                         900.71
# 23                         177.84                         168.44
# 24                           1.00                           0.73
# 25                         413.58                         398.22
# 26                           9.84                           9.78
# 28                         152.40                         145.96
# 29                         539.78                         520.00
# 30                         341.40                         324.87
# 31                          69.27                          65.64
# 32                          14.91                          13.42
# 33                         173.00                         163.18
# 34                         450.09                         432.20
# 35                         333.91                         320.93
# 36                         103.36                          97.62
# 37                          43.71                          41.82
# 38                           6.04                           6.51
# 39                           7.64                           7.62
# 40                         202.44                         191.44
# 41                          92.93                          90.13
# 42                         332.24                         319.07
# 43                         133.09                         127.80
# 44                         125.71                         120.11
# 45                         231.33                         221.33
# 46                          65.40                          63.11
# 47                         208.18                         198.18
# 48                         350.02                         335.76
# 49                         247.16                         238.11
# 50                         142.87                         137.47
# 51                          25.31                          22.87
# 52                          78.82                          74.40
# 53                         586.13                         563.49
# 54                         527.49                         502.47
# 56                           4.13                           3.93
# 57                         990.80                         945.38
# 58                         114.38                         112.40
# 59                          12.58                          12.11
# 60                         839.16                         800.71
# 61                         278.60                         269.18
#
#     Score for reward function 281  Score for reward function 282  \
# 0                          332.09                         295.62
# 1                          209.38                         183.09
# 4                         1005.38                         900.02
# 5                          173.24                         158.40
# 7                          621.27                         547.00
# 8                          537.24                         491.53
# 9                            6.53                           4.78
# 10                         583.02                         512.33
# 11                         391.64                         353.44
# 12                         162.69                         157.13
# 13                          33.36                          28.60
# 14                           6.73                           5.02
# 15                           1.18                           1.89
# 16                        1151.51                        1032.49
# 17                          21.40                          19.82
# 22                         993.42                         882.93
# 23                         184.44                         174.56
# 24                           0.76                           0.93
# 25                         437.80                         389.93
# 26                          11.80                           8.69
# 28                         158.78                         147.93
# 29                         573.04                         509.93
# 30                         360.53                         323.02
# 31                          71.31                          63.44
# 32                          14.96                          14.09
# 33                         188.09                         158.27
# 34                         483.62                         432.51
# 35                         340.13                         314.78
# 36                         109.89                          98.13
# 37                          43.29                          40.87
# 38                           6.00                           6.00
# 39                           7.60                           7.87
# 40                         220.42                         187.38
# 41                          96.47                          89.78
# 42                         346.64                         321.87
# 43                         141.38                         124.24
# 44                         133.38                         116.40
# 45                         240.33                         218.76
# 46                          66.49                          99.69
# 47                         213.98                         231.09
# 48                         368.60                         303.71
# 49                         264.64                         212.93
# 50                         151.11                         126.56
# 51                          24.82                          20.22
# 52                          88.98                          64.22
# 53                         608.96                         566.98
# 54                         566.07                         486.78
# 56                           3.60                           4.67
# 57                        1044.27                         935.44
# 58                         120.29                         111.09
# 59                          14.07                          11.89
# 60                         887.80                         788.44
# 61                         290.82                         269.98
#
#     Score for reward function 283  Score for reward function 284
# 0                          322.00                         299.87
# 1                          197.38                         184.29
# 4                          972.00                         908.40
# 5                          171.49                         161.49
# 7                          595.78                         563.64
# 8                          524.49                         487.58
# 9                            7.73                           5.11
# 10                         559.20                         527.60
# 11                         377.02                         355.31
# 12                         166.51                         152.40
# 13                          31.02                          27.71
# 14                           7.80                           5.62
# 15                           1.93                           1.24
# 16                        1116.09                        1046.00
# 17                          21.18                          17.38
# 22                         954.64                         900.71
# 23                         187.64                         168.44
# 24                           1.20                           0.73
# 25                         416.27                         398.22
# 26                          12.53                           9.78
# 28                         159.98                         145.96
# 29                         553.82                         520.00
# 30                         345.69                         324.87
# 31                          69.71                          65.64
# 32                          14.29                          13.42
# 33                         179.22                         163.18
# 34                         474.69                         432.20
# 35                         332.91                         320.93
# 36                         101.40                          97.62
# 37                          42.09                          41.82
# 38                           6.18                           6.51
# 39                           7.00                           7.62
# 40                         215.11                         191.44
# 41                          89.07                          90.13
# 42                         336.49                         319.07
# 43                         133.02                         127.80
# 44                         129.69                         120.11
# 45                         240.11                         221.33
# 46                          73.13                          63.11
# 47                         239.47                         198.18
# 48                         414.71                         335.76
# 49                         210.62                         238.11
# 50                         122.96                         137.47
# 51                          19.64                          22.87
# 52                          62.96                          74.40
# 53                         593.07                         563.49
# 54                         545.89                         502.47
# 56                           4.53                           3.93
# 57                        1006.84                         945.38
# 58                         123.98                         112.40
# 59                          12.67                          12.11
# 60                         865.09                         800.71
# 61                         278.40                         269.18
#
# [53 rows x 287 columns]

# %%
scores = [
    np.array((df['Score for reward function ' + str(i)])) for i in range(285)
]

# %% [markdown]
# ## Initialize parameters

# %%
alpha = 0.60
N = 53
p_grid = generate_p_grid(N=N, alpha=alpha, grid_size=500)

alpha_values = [0.05 * j for j in range(2, 20)] + [0.99]

# %% [markdown]
# ## Helper functions

# %%
def get_optimum_policy(p):
    return get_optimum_vector(vectors=scores, p=p)

def get_performance(policy, p):
    return generalized_p_mean(x=policy, p=p)

optimal_values = {
    p: get_performance(get_optimum_policy(p), p) for p in tqdm(p_grid)
}

def get_optimal_value(p):
    if p in optimal_values.keys():
        return optimal_values[p]
    else:
        return get_performance(Policy(get_optimum_policy(p)), p)
# Out:
# 100%|██████████| 500/500 [00:03<00:00, 159.97it/s]

# %% [markdown]
# # Compute portfolios

# %% [markdown]
# ## Heuristic portfolio

# %%
heuristic_results = pd.DataFrame(
    columns=['K', 'portfolio_size', 'approximation', 'p_values']
)
heuristic_results.set_index('K', inplace=True)

for K in range(1, 11):
    heuristic_portfolio = budget_portfolio_with_suboptimalities(
        initial_p=-100, K=K, get_optimum_policy=get_optimum_policy, get_performance=get_performance,
    )

    print('p values', [policy.p for policy in heuristic_portfolio])

    heuristic_approximation = compute_portfolio_worst_approx_ratio(
        portfolio=heuristic_portfolio, get_performance=get_performance,
        get_optimal_value=get_optimal_value, p_grid=p_grid
    )

    heuristic_results.at[K, 'portfolio_size'] = len(heuristic_portfolio)
    heuristic_results.at[K, 'approximation'] = heuristic_approximation
    heuristic_results.at[K, 'p_values'] = [round(policy.p, 3) for policy in heuristic_portfolio]

    print(heuristic_approximation)
# Out:
# p values [-100]
# 0.9383407578022731
# p values [-100, 1.0]
# 0.9383407578022731
# p values [-100, 1.0, -49.5]
# 0.9383407578022731
# p values [-100, 1.0, -49.5, -24.25]
# 0.9383407578022731
# p values [-100, 1.0, -49.5, -24.25, -11.625]
# 0.9383407578022731
# p values [-100, 1.0, -49.5, -24.25, -11.625, -5.3125]
# 0.9822052471912309
# p values [-100, 1.0, -49.5, -24.25, -11.625, -5.3125, -2.15625]
# 0.9822052471912309
# p values [-100, 1.0, -49.5, -24.25, -11.625, -5.3125, -2.15625, -0.578125]
# 0.9858470422981619
# p values [-100, 1.0, -49.5, -24.25, -11.625, -5.3125, -2.15625, -0.578125, 0.2109375]
# 0.9866862263519582
# p values [-100, 1.0, -49.5, -24.25, -11.625, -5.3125, -2.15625, -0.578125, 0.2109375, -0.18359375]
# 0.9906965584829375

# %%
heuristic_results
# Out:
#    portfolio_size approximation  \
# K
# 1               1      0.938341
# 2               2      0.938341
# 3               3      0.938341
# 4               4      0.938341
# 5               5      0.938341
# 6               6      0.982205
# 7               7      0.982205
# 8               8      0.985847
# 9               9      0.986686
# 10             10      0.990697
#
#                                              p_values
# K
# 1                                              [-100]
# 2                                         [-100, 1.0]
# 3                                  [-100, 1.0, -49.5]
# 4                          [-100, 1.0, -49.5, -24.25]
# 5                 [-100, 1.0, -49.5, -24.25, -11.625]
# 6         [-100, 1.0, -49.5, -24.25, -11.625, -5.312]
# 7   [-100, 1.0, -49.5, -24.25, -11.625, -5.312, -2...
# 8   [-100, 1.0, -49.5, -24.25, -11.625, -5.312, -2...
# 9   [-100, 1.0, -49.5, -24.25, -11.625, -5.312, -2...
# 10  [-100, 1.0, -49.5, -24.25, -11.625, -5.312, -2...

# %%
heuristic_results.to_csv('../../data/sclm_real_world/portfolios/heuristic_portfolio.csv')

# %% [markdown]
# ## p-Mean Portfolio with Line Search

# %%
line_search_results = pd.DataFrame(
    columns=['K', 'alpha', 'oracle_calls', 'approximation', 'p_values']
)
line_search_results.set_index('K', inplace=True)

for alpha in alpha_values:
    line_search_portfolio = portfolio_with_line_search(
        get_optimum_policy=get_optimum_policy, get_performance=get_performance, d=len(scores[0]), alpha=alpha
    )

    print('alpha:', alpha)
    print('p values:', [policy.p for policy in line_search_portfolio])
    print('oracle calls:', line_search_portfolio.oracle_calls)
    print('portfolio size:', len(line_search_portfolio))

    K = len(line_search_portfolio)

    if not K in line_search_results.index:
        line_search_approximation = compute_portfolio_worst_approx_ratio(
            portfolio=line_search_portfolio, get_performance=get_performance,
            get_optimal_value=get_optimal_value, p_grid=p_grid
        )
        line_search_results.at[K, 'alpha'] = alpha
        line_search_results.at[K, 'oracle_calls'] = line_search_portfolio.oracle_calls
        line_search_results.at[K, 'approximation'] = line_search_approximation
        line_search_results.at[K, 'p_values'] = [round(policy.p, 3) for policy in line_search_portfolio]
        
        if line_search_approximation == 1.0:
            print('Found optimal portfolio for alpha =', alpha)
            break

        print('approximation:', line_search_approximation)
# Out:
# alpha: 0.1
# p values: [np.float64(-1.7242758696007894)]
# oracle calls: 2
# portfolio size: 1
# approximation: 0.9235673961490934
# alpha: 0.15000000000000002
# p values: [np.float64(-2.0927995831486377)]
# oracle calls: 2
# portfolio size: 1
# alpha: 0.2
# p values: [np.float64(-2.4668810662894636)]
# oracle calls: 3
# portfolio size: 1
# alpha: 0.25
# p values: [np.float64(-2.8639602272816), np.float64(0.034009943179600044)]
# oracle calls: 7
# portfolio size: 2
# approximation: 0.9820359281437125
# alpha: 0.30000000000000004
# p values: [np.float64(-3.2976591325706526), np.float64(-0.07441478314266314)]
# oracle calls: 7
# portfolio size: 2
# alpha: 0.35000000000000003
# p values: [np.float64(-3.7818710626317373), np.float64(-0.19546776565793433)]
# oracle calls: 8
# portfolio size: 2
# alpha: 0.4
# p values: [np.float64(-4.333004553512617), np.float64(-0.33325113837815423), np.float64(0.3333744308109229)]
# oracle calls: 11
# portfolio size: 3
# approximation: 0.9820359281437125
# alpha: 0.45
# p values: [np.float64(-4.972139820765523), np.float64(-0.49303495519138085), np.float64(0.2534825224043096)]
# oracle calls: 11
# portfolio size: 3
# alpha: 0.5
# p values: [np.float64(-5.7279204545632), np.float64(-0.26148508523059993), np.float64(0.36925745738470006)]
# oracle calls: 15
# portfolio size: 3
# alpha: 0.55
# p values: [np.float64(-6.641094325934954), np.float64(-0.43270518611280395), np.float64(-0.07452888958460296), np.float64(0.4627355552076985)]
# oracle calls: 19
# portfolio size: 4
# approximation: 0.9820359281437125
# alpha: 0.6000000000000001
# p values: [np.float64(-7.772303754619237), np.float64(-0.23360521549333024), np.float64(0.3831973922533349)]
# oracle calls: 19
# portfolio size: 3
# alpha: 0.65
# p values: [np.float64(-9.2164562828207), np.float64(-4.10822814141035), np.float64(-0.43668916477166086), np.float64(-0.07751687357874565), np.float64(0.46124156321062715)]
# oracle calls: 23
# portfolio size: 5
# approximation: 0.9937204501890369
# alpha: 0.7000000000000001
# p values: [np.float64(-11.131401240884802), np.float64(-5.065700620442401), np.float64(-0.4927310120619971), np.float64(-0.11954825904649782), np.float64(0.5801694028575634)]
# oracle calls: 34
# portfolio size: 5
# alpha: 0.75
# p values: [np.float64(-13.800970911100455), np.float64(-6.4004854555502275), np.float64(-0.593561565379712), np.float64(-0.22007057349384201), np.float64(0.0849470698796185), np.float64(0.5424735349398092)]
# oracle calls: 46
# portfolio size: 6
# approximation: 0.9991761359253057
# alpha: 0.8
# p values: [np.float64(-17.792546054631583), np.float64(-3.6981365136578956), np.float64(-0.5491032703191141), np.float64(-0.1860321913380717), np.float64(-0.03777816742081273), np.float64(0.22166637443439044), np.float64(0.6108331872171953)]
# oracle calls: 61
# portfolio size: 7
# Found optimal portfolio for alpha = 0.8

# %%
line_search_results
# Out:
#   alpha oracle_calls approximation  \
# K
# 1   0.1            2      0.923567
# 2  0.25            7      0.982036
# 3   0.4           11      0.982036
# 4  0.55           19      0.982036
# 5  0.65           23       0.99372
# 6  0.75           46      0.999176
# 7   0.8           61           1.0
#
#                                             p_values
# K
# 1                                           [-1.724]
# 2                                    [-2.864, 0.034]
# 3                            [-4.333, -0.333, 0.333]
# 4                    [-6.641, -0.433, -0.075, 0.463]
# 5            [-9.216, -4.108, -0.437, -0.078, 0.461]
# 6       [-13.801, -6.4, -0.594, -0.22, 0.085, 0.542]
# 7  [-17.793, -3.698, -0.549, -0.186, -0.038, 0.22...

# %%
line_search_results.to_csv('../../data/sclm_real_world/portfolios/line_search_portfolio.csv')

# %% [markdown]
# ## Random norm portfolio

# %%
alpha_0 = 0.90
initial_p = - np.log(N)/np.log(1/alpha_0)

K_values = np.arange(1, 10)
random_norm_results = pd.DataFrame(columns=['K', 'approximation'])
random_norm_results.set_index('K', inplace=True)

T = 10

for K in K_values:
    avg_approximation = 0
    for t in range(T):
        portfolio_random_norm_sample = portfolio_of_random_norms(
            initial_p=initial_p,
            K=K,
            get_optimum_policy=get_optimum_policy,
            seed=t
        )
        actual_approximation_random_norm_sample = compute_portfolio_worst_approx_ratio(
            portfolio=portfolio_random_norm_sample,
            get_optimal_value=get_optimal_value,
            p_grid=p_grid,
            get_performance=get_performance
        )
        actual_approximation_random_norm_sample = np.round(actual_approximation_random_norm_sample, 4)
        avg_approximation += actual_approximation_random_norm_sample

    avg_approximation /= T
    random_norm_results.at[K, 'approximation'] = avg_approximation

    print('K = ' + str(K) + ', actual approximation = ' + str(avg_approximation))
# Out:
# K = 1, actual approximation = 0.91339
# K = 2, actual approximation = 0.9418300000000001
# K = 3, actual approximation = 0.9418300000000001
# K = 4, actual approximation = 0.9418300000000001
# K = 5, actual approximation = 0.9468800000000002
# K = 6, actual approximation = 0.9468800000000002
# K = 7, actual approximation = 0.9471
# K = 8, actual approximation = 0.9471
# K = 9, actual approximation = 0.9471

# %%
random_norm_results.to_csv('../../data/sclm_real_world/portfolios/random_norm_portfolio.csv')

# %% [markdown]
# ## Random policy portfolio

# %%
K_values = np.arange(1, 10)
random_policy_results = pd.DataFrame(columns=['K', 'approximation'])
random_policy_results.set_index('K', inplace=True)

T = 10

for K in K_values:
    avg_approximation = 0
    for t in range(T):
        portfolio_random_policy = portfolio_of_random_policies(
            policies=[Policy(scores[i]) for i in range(len(scores))], K=K
        )
        actual_approximation_random_policy = compute_portfolio_worst_approx_ratio(
            portfolio=portfolio_random_policy,
            get_optimal_value=get_optimal_value,
            p_grid=p_grid,
            get_performance=get_performance
        )
        avg_approximation += actual_approximation_random_policy
    avg_approximation = np.round(avg_approximation/T, 4)
    random_policy_results.loc[K, 'approximation'] = avg_approximation

    print('K = ' + str(K) + ', actual approximation = ' + str(avg_approximation))
# Out:
# K = 1, actual approximation = 0.5925
# K = 2, actual approximation = 0.5381
# K = 3, actual approximation = 0.5822
# K = 4, actual approximation = 0.5912
# K = 5, actual approximation = 0.5969
# K = 6, actual approximation = 0.6547
# K = 7, actual approximation = 0.6824
# K = 8, actual approximation = 0.6234
# K = 9, actual approximation = 0.6556

# %%
random_policy_results.to_csv('../../data/sclm_real_world/portfolios/random_policy_portfolio.csv')

# %% [markdown]
# ## GPI Portfolio

# %%
gpi_results = pd.DataFrame(
    columns=['K', 'approximation']
)

gpi_results.set_index('K', inplace=True)

gpi_portfolio = portfolio_with_gpi(vectors=scores)
policies = list(gpi_portfolio.policies)

for K in range(1, len(gpi_portfolio) + 1):
    portfolio = Portfolio()
    for i in range(K):
        portfolio.add_policy(policies[i])

    gpi_approximation = compute_portfolio_worst_approx_ratio(
        portfolio=portfolio, get_performance=get_performance,
        get_optimal_value=get_optimal_value, p_grid=p_grid
    )

    print('K:', K)
    print('Approximation:', gpi_approximation)

    gpi_results.loc[K, 'approximation'] = gpi_approximation
# Out:
# Iteration 0
# differential_evolution step 1: f(x)= -5.4513980937084625
# differential_evolution step 2: f(x)= -5.4513980937084625
# differential_evolution step 3: f(x)= -5.895473938657972
# differential_evolution step 4: f(x)= -5.9707902024536565
# differential_evolution step 5: f(x)= -5.9707902024536565
# differential_evolution step 6: f(x)= -5.9707902024536565
# differential_evolution step 7: f(x)= -5.9707902024536565
# differential_evolution step 8: f(x)= -5.987761246136586
# differential_evolution step 9: f(x)= -5.987761246136586
# differential_evolution step 10: f(x)= -6.027808261971586
# differential_evolution step 11: f(x)= -6.521153808260237
# differential_evolution step 12: f(x)= -6.521153808260237
# differential_evolution step 13: f(x)= -6.576372548918812
# differential_evolution step 14: f(x)= -6.853563353821414
# differential_evolution step 15: f(x)= -6.974905639316944
# differential_evolution step 16: f(x)= -6.974905639316944
# differential_evolution step 17: f(x)= -7.52346633794798
# differential_evolution step 18: f(x)= -7.52346633794798
# differential_evolution step 19: f(x)= -7.52346633794798
# differential_evolution step 20: f(x)= -7.672658723888219
# differential_evolution step 21: f(x)= -7.672658723888219
# differential_evolution step 22: f(x)= -7.672658723888219
# differential_evolution step 23: f(x)= -7.672658723888219
# differential_evolution step 24: f(x)= -7.672658723888219
# differential_evolution step 25: f(x)= -7.672658723888219
# differential_evolution step 26: f(x)= -7.672658723888219
# differential_evolution step 27: f(x)= -7.674308879621719
# differential_evolution step 28: f(x)= -7.801993310755336
# differential_evolution step 29: f(x)= -7.998148472609216
# differential_evolution step 30: f(x)= -7.998148472609216
# differential_evolution step 31: f(x)= -7.998148472609216
# differential_evolution step 32: f(x)= -7.998148472609216
# differential_evolution step 33: f(x)= -7.998148472609216
# differential_evolution step 34: f(x)= -7.998148472609216
# differential_evolution step 35: f(x)= -7.998148472609216
# differential_evolution step 36: f(x)= -8.077781178257965
# differential_evolution step 37: f(x)= -8.368470510663201
# differential_evolution step 38: f(x)= -8.41678113516491
# differential_evolution step 39: f(x)= -8.713326227002256
# differential_evolution step 40: f(x)= -8.713326227002256
# differential_evolution step 41: f(x)= -8.713326227002256
# differential_evolution step 42: f(x)= -8.896801393786632
# differential_evolution step 43: f(x)= -8.896801393786632
# differential_evolution step 44: f(x)= -9.041932025841845
# differential_evolution step 45: f(x)= -9.041932025841845
# differential_evolution step 46: f(x)= -9.041932025841845
# differential_evolution step 47: f(x)= -9.041932025841845
# differential_evolution step 48: f(x)= -9.352592384386526
# differential_evolution step 49: f(x)= -9.352592384386526
# differential_evolution step 50: f(x)= -9.352592384386526
# differential_evolution step 51: f(x)= -9.352592384386526
# differential_evolution step 52: f(x)= -10.130349450738606
# differential_evolution step 53: f(x)= -10.130349450738606
# differential_evolution step 54: f(x)= -10.130349450738606
# differential_evolution step 55: f(x)= -10.130349450738606
# differential_evolution step 56: f(x)= -10.130349450738606
# differential_evolution step 57: f(x)= -10.130349450738606
# differential_evolution step 58: f(x)= -10.130349450738606
# differential_evolution step 59: f(x)= -10.329044076707476
# differential_evolution step 60: f(x)= -10.329044076707476
# differential_evolution step 61: f(x)= -10.329044076707476
# differential_evolution step 62: f(x)= -10.329044076707476
# differential_evolution step 63: f(x)= -10.329044076707476
# differential_evolution step 64: f(x)= -10.329044076707476
# differential_evolution step 65: f(x)= -10.329044076707476
# differential_evolution step 66: f(x)= -10.329044076707476
# differential_evolution step 67: f(x)= -10.329044076707476
# differential_evolution step 68: f(x)= -10.329044076707476
# differential_evolution step 69: f(x)= -10.329044076707476
# differential_evolution step 70: f(x)= -10.329044076707476
# differential_evolution step 71: f(x)= -10.329044076707476
# differential_evolution step 72: f(x)= -10.329044076707476
# differential_evolution step 73: f(x)= -10.329044076707476
# differential_evolution step 74: f(x)= -10.329044076707476
# differential_evolution step 75: f(x)= -10.329044076707476
# differential_evolution step 76: f(x)= -10.329044076707476
# differential_evolution step 77: f(x)= -10.329044076707476
# differential_evolution step 78: f(x)= -10.51247995556156
# differential_evolution step 79: f(x)= -10.51247995556156
# differential_evolution step 80: f(x)= -10.51247995556156
# differential_evolution step 81: f(x)= -10.51247995556156
# differential_evolution step 82: f(x)= -10.51247995556156
# differential_evolution step 83: f(x)= -10.51247995556156
# differential_evolution step 84: f(x)= -10.51247995556156
# differential_evolution step 85: f(x)= -10.51247995556156
# differential_evolution step 86: f(x)= -10.51247995556156
# differential_evolution step 87: f(x)= -10.51247995556156
# differential_evolution step 88: f(x)= -10.51247995556156
# differential_evolution step 89: f(x)= -10.51247995556156
# differential_evolution step 90: f(x)= -10.51247995556156
# differential_evolution step 91: f(x)= -10.51247995556156
# differential_evolution step 92: f(x)= -10.51247995556156
# differential_evolution step 93: f(x)= -10.51247995556156
# differential_evolution step 94: f(x)= -10.51247995556156
# differential_evolution step 95: f(x)= -10.51247995556156
# differential_evolution step 96: f(x)= -10.649308556992878
# differential_evolution step 97: f(x)= -10.857321680917835
# differential_evolution step 98: f(x)= -10.857321680917835
# differential_evolution step 99: f(x)= -10.857321680917835
# differential_evolution step 100: f(x)= -10.857321680917835
# differential_evolution step 101: f(x)= -10.857321680917835
# differential_evolution step 102: f(x)= -10.857321680917835
# differential_evolution step 103: f(x)= -10.857321680917835
# differential_evolution step 104: f(x)= -10.857321680917835
# differential_evolution step 105: f(x)= -10.857321680917835
# differential_evolution step 106: f(x)= -10.857321680917835
# differential_evolution step 107: f(x)= -10.857321680917835
# differential_evolution step 108: f(x)= -10.857321680917835
# differential_evolution step 109: f(x)= -10.857321680917835
# differential_evolution step 110: f(x)= -10.857321680917835
# differential_evolution step 111: f(x)= -10.857321680917835
# differential_evolution step 112: f(x)= -10.857321680917835
# differential_evolution step 113: f(x)= -10.857321680917835
# differential_evolution step 114: f(x)= -10.857321680917835
# differential_evolution step 115: f(x)= -10.857321680917835
# differential_evolution step 116: f(x)= -10.857321680917835
# differential_evolution step 117: f(x)= -10.857321680917835
# differential_evolution step 118: f(x)= -10.857321680917835
# differential_evolution step 119: f(x)= -10.857321680917835
# differential_evolution step 120: f(x)= -10.857321680917835
# differential_evolution step 121: f(x)= -10.857321680917835
# differential_evolution step 122: f(x)= -10.857321680917835
# differential_evolution step 123: f(x)= -10.857321680917835
# differential_evolution step 124: f(x)= -10.857321680917835
# differential_evolution step 125: f(x)= -10.857321680917835
# differential_evolution step 126: f(x)= -10.857321680917835
# differential_evolution step 127: f(x)= -10.857321680917835
# differential_evolution step 128: f(x)= -10.857321680917835
# differential_evolution step 129: f(x)= -10.857321680917835
# differential_evolution step 130: f(x)= -10.857321680917835
# differential_evolution step 131: f(x)= -10.857321680917835
# differential_evolution step 132: f(x)= -10.857321680917835
# differential_evolution step 133: f(x)= -10.857321680917835
# differential_evolution step 134: f(x)= -10.857321680917835
# differential_evolution step 135: f(x)= -10.857321680917835
# differential_evolution step 136: f(x)= -10.857321680917835
# differential_evolution step 137: f(x)= -10.857321680917835
# differential_evolution step 138: f(x)= -10.857321680917835
# differential_evolution step 139: f(x)= -10.857321680917835
# differential_evolution step 140: f(x)= -10.857321680917835
# differential_evolution step 141: f(x)= -10.857321680917835
# differential_evolution step 142: f(x)= -10.857321680917835
# differential_evolution step 143: f(x)= -11.45400159506653
# differential_evolution step 144: f(x)= -11.45400159506653
# differential_evolution step 145: f(x)= -11.591654723520094
# differential_evolution step 146: f(x)= -11.591654723520094
# differential_evolution step 147: f(x)= -11.591654723520094
# differential_evolution step 148: f(x)= -11.591654723520094
# differential_evolution step 149: f(x)= -11.591654723520094
# differential_evolution step 150: f(x)= -11.591654723520094
# differential_evolution step 151: f(x)= -11.591654723520094
# differential_evolution step 152: f(x)= -11.591654723520094
# differential_evolution step 153: f(x)= -11.591654723520094
# differential_evolution step 154: f(x)= -11.591654723520094
# differential_evolution step 155: f(x)= -11.591654723520094
# differential_evolution step 156: f(x)= -11.591654723520094
# differential_evolution step 157: f(x)= -11.591654723520094
# differential_evolution step 158: f(x)= -11.591654723520094
# differential_evolution step 159: f(x)= -11.591654723520094
# differential_evolution step 160: f(x)= -11.591654723520094
# differential_evolution step 161: f(x)= -11.591654723520094
# differential_evolution step 162: f(x)= -11.591654723520094
# differential_evolution step 163: f(x)= -11.591654723520094
# differential_evolution step 164: f(x)= -12.045516132086732
# differential_evolution step 165: f(x)= -12.045516132086732
# differential_evolution step 166: f(x)= -12.045516132086732
# differential_evolution step 167: f(x)= -12.045516132086732
# differential_evolution step 168: f(x)= -12.045516132086732
# differential_evolution step 169: f(x)= -12.045516132086732
# differential_evolution step 170: f(x)= -12.045516132086732
# differential_evolution step 171: f(x)= -12.045516132086732
# differential_evolution step 172: f(x)= -12.045516132086732
# differential_evolution step 173: f(x)= -12.045516132086732
# differential_evolution step 174: f(x)= -12.045516132086732
# differential_evolution step 175: f(x)= -12.045516132086732
# differential_evolution step 176: f(x)= -12.045516132086732
# differential_evolution step 177: f(x)= -12.045516132086732
# differential_evolution step 178: f(x)= -12.045516132086732
# differential_evolution step 179: f(x)= -12.045516132086732
# differential_evolution step 180: f(x)= -12.045516132086732
# differential_evolution step 181: f(x)= -12.045516132086732
# differential_evolution step 182: f(x)= -12.045516132086732
# differential_evolution step 183: f(x)= -12.045516132086732
# differential_evolution step 184: f(x)= -12.045516132086732
# differential_evolution step 185: f(x)= -12.045516132086732
# differential_evolution step 186: f(x)= -12.045516132086732
# differential_evolution step 187: f(x)= -12.045516132086732
# differential_evolution step 188: f(x)= -12.287190301222495
# differential_evolution step 189: f(x)= -12.287190301222495
# differential_evolution step 190: f(x)= -12.287190301222495
# differential_evolution step 191: f(x)= -12.287190301222495
# differential_evolution step 192: f(x)= -12.287190301222495
# differential_evolution step 193: f(x)= -12.287190301222495
# differential_evolution step 194: f(x)= -12.287190301222495
# differential_evolution step 195: f(x)= -12.287190301222495
# differential_evolution step 196: f(x)= -12.287190301222495
# differential_evolution step 197: f(x)= -12.287190301222495
# differential_evolution step 198: f(x)= -12.287190301222495
# differential_evolution step 199: f(x)= -12.287190301222495
# differential_evolution step 200: f(x)= -12.287190301222495
# differential_evolution step 201: f(x)= -12.287190301222495
# differential_evolution step 202: f(x)= -12.287190301222495
# differential_evolution step 203: f(x)= -12.287190301222495
# differential_evolution step 204: f(x)= -12.287190301222495
# differential_evolution step 205: f(x)= -12.287190301222495
# differential_evolution step 206: f(x)= -12.462667508614231
# differential_evolution step 207: f(x)= -12.462667508614231
# differential_evolution step 208: f(x)= -12.462667508614231
# differential_evolution step 209: f(x)= -12.462667508614231
# differential_evolution step 210: f(x)= -12.609612218178427
# differential_evolution step 211: f(x)= -12.609612218178427
# differential_evolution step 212: f(x)= -12.609612218178427
# differential_evolution step 213: f(x)= -12.609612218178427
# differential_evolution step 214: f(x)= -12.609612218178427
# differential_evolution step 215: f(x)= -12.609612218178427
# differential_evolution step 216: f(x)= -12.609612218178427
# differential_evolution step 217: f(x)= -12.609612218178427
# differential_evolution step 218: f(x)= -12.609612218178427
# differential_evolution step 219: f(x)= -12.609612218178427
# differential_evolution step 220: f(x)= -12.783912974892019
# differential_evolution step 221: f(x)= -12.783912974892019
# differential_evolution step 222: f(x)= -12.783912974892019
# differential_evolution step 223: f(x)= -12.783912974892019
# differential_evolution step 224: f(x)= -12.783912974892019
# differential_evolution step 225: f(x)= -12.783912974892019
# differential_evolution step 226: f(x)= -12.783912974892019
# differential_evolution step 227: f(x)= -12.783912974892019
# differential_evolution step 228: f(x)= -12.955533113620504
# differential_evolution step 229: f(x)= -12.955533113620504
# differential_evolution step 230: f(x)= -12.955533113620504
# differential_evolution step 231: f(x)= -12.983679583270657
# differential_evolution step 232: f(x)= -12.983679583270657
# differential_evolution step 233: f(x)= -12.983679583270657
# differential_evolution step 234: f(x)= -12.983679583270657
# differential_evolution step 235: f(x)= -12.983679583270657
# differential_evolution step 236: f(x)= -12.983679583270657
# differential_evolution step 237: f(x)= -12.983679583270657
# differential_evolution step 238: f(x)= -12.983679583270657
# differential_evolution step 239: f(x)= -12.983679583270657
# differential_evolution step 240: f(x)= -12.983679583270657
# differential_evolution step 241: f(x)= -12.983679583270657
# differential_evolution step 242: f(x)= -12.983679583270657
# differential_evolution step 243: f(x)= -12.983679583270657
# differential_evolution step 244: f(x)= -12.983679583270657
# differential_evolution step 245: f(x)= -12.983679583270657
# differential_evolution step 246: f(x)= -12.983679583270657
# differential_evolution step 247: f(x)= -12.983679583270657
# differential_evolution step 248: f(x)= -12.983679583270657
# differential_evolution step 249: f(x)= -12.983679583270657
# differential_evolution step 250: f(x)= -12.983679583270657
# Polishing solution with 'L-BFGS-B'
# Iteration 1
# differential_evolution step 1: f(x)= -5.17825205126303
# differential_evolution step 2: f(x)= -5.592393685418756
# differential_evolution step 3: f(x)= -5.592393685418756
# differential_evolution step 4: f(x)= -5.592393685418756
# differential_evolution step 5: f(x)= -5.592393685418756
# differential_evolution step 6: f(x)= -5.915492350583634
# differential_evolution step 7: f(x)= -6.727832499098383
# differential_evolution step 8: f(x)= -7.0407913247585725
# differential_evolution step 9: f(x)= -7.0407913247585725
# differential_evolution step 10: f(x)= -7.466343815620121
# differential_evolution step 11: f(x)= -7.466343815620121
# differential_evolution step 12: f(x)= -7.466343815620121
# differential_evolution step 13: f(x)= -7.746820025941815
# differential_evolution step 14: f(x)= -7.746820025941815
# differential_evolution step 15: f(x)= -7.746820025941815
# differential_evolution step 16: f(x)= -7.761477046566256
# differential_evolution step 17: f(x)= -7.839801899468966
# differential_evolution step 18: f(x)= -7.902373155284863
# differential_evolution step 19: f(x)= -7.902373155284863
# differential_evolution step 20: f(x)= -7.902373155284863
# differential_evolution step 21: f(x)= -7.902373155284863
# differential_evolution step 22: f(x)= -7.902373155284863
# differential_evolution step 23: f(x)= -7.902373155284863
# differential_evolution step 24: f(x)= -7.902373155284863
# differential_evolution step 25: f(x)= -7.902373155284863
# differential_evolution step 26: f(x)= -7.902373155284863
# differential_evolution step 27: f(x)= -7.902373155284863
# differential_evolution step 28: f(x)= -7.902373155284863
# differential_evolution step 29: f(x)= -7.966346924628851
# differential_evolution step 30: f(x)= -7.966346924628851
# differential_evolution step 31: f(x)= -7.997504776780829
# differential_evolution step 32: f(x)= -7.997504776780829
# differential_evolution step 33: f(x)= -7.997504776780829
# differential_evolution step 34: f(x)= -7.997504776780829
# differential_evolution step 35: f(x)= -7.997504776780829
# differential_evolution step 36: f(x)= -7.997504776780829
# differential_evolution step 37: f(x)= -7.997504776780829
# differential_evolution step 38: f(x)= -7.997504776780829
# differential_evolution step 39: f(x)= -7.997504776780829
# differential_evolution step 40: f(x)= -7.997504776780829
# differential_evolution step 41: f(x)= -8.028002382052819
# differential_evolution step 42: f(x)= -8.278696742332329
# differential_evolution step 43: f(x)= -8.403372956991404
# differential_evolution step 44: f(x)= -8.403372956991404
# differential_evolution step 45: f(x)= -8.403372956991404
# differential_evolution step 46: f(x)= -8.403372956991404
# differential_evolution step 47: f(x)= -8.403372956991404
# differential_evolution step 48: f(x)= -8.403372956991404
# differential_evolution step 49: f(x)= -8.403372956991404
# differential_evolution step 50: f(x)= -8.403372956991404
# differential_evolution step 51: f(x)= -8.403372956991404
# differential_evolution step 52: f(x)= -8.403372956991404
# differential_evolution step 53: f(x)= -8.403372956991404
# differential_evolution step 54: f(x)= -8.403372956991404
# differential_evolution step 55: f(x)= -8.403372956991404
# differential_evolution step 56: f(x)= -8.403372956991404
# differential_evolution step 57: f(x)= -8.478386165305778
# differential_evolution step 58: f(x)= -8.478386165305778
# differential_evolution step 59: f(x)= -8.478386165305778
# differential_evolution step 60: f(x)= -8.478386165305778
# differential_evolution step 61: f(x)= -8.902972508110054
# differential_evolution step 62: f(x)= -8.902972508110054
# differential_evolution step 63: f(x)= -8.902972508110054
# differential_evolution step 64: f(x)= -8.902972508110054
# differential_evolution step 65: f(x)= -8.902972508110054
# differential_evolution step 66: f(x)= -8.902972508110054
# differential_evolution step 67: f(x)= -8.902972508110054
# differential_evolution step 68: f(x)= -8.902972508110054
# differential_evolution step 69: f(x)= -8.902972508110054
# differential_evolution step 70: f(x)= -8.902972508110054
# differential_evolution step 71: f(x)= -8.902972508110054
# differential_evolution step 72: f(x)= -8.902972508110054
# differential_evolution step 73: f(x)= -8.902972508110054
# differential_evolution step 74: f(x)= -8.902972508110054
# differential_evolution step 75: f(x)= -8.902972508110054
# differential_evolution step 76: f(x)= -8.902972508110054
# differential_evolution step 77: f(x)= -8.902972508110054
# differential_evolution step 78: f(x)= -8.902972508110054
# differential_evolution step 79: f(x)= -9.113580509503038
# differential_evolution step 80: f(x)= -9.113580509503038
# differential_evolution step 81: f(x)= -9.113580509503038
# differential_evolution step 82: f(x)= -9.425296260835069
# differential_evolution step 83: f(x)= -9.425296260835069
# differential_evolution step 84: f(x)= -9.425296260835069
# differential_evolution step 85: f(x)= -9.425296260835069
# differential_evolution step 86: f(x)= -9.425296260835069
# differential_evolution step 87: f(x)= -9.425296260835069
# differential_evolution step 88: f(x)= -9.425296260835069
# differential_evolution step 89: f(x)= -9.425296260835069
# differential_evolution step 90: f(x)= -9.425296260835069
# differential_evolution step 91: f(x)= -9.425296260835069
# differential_evolution step 92: f(x)= -9.425296260835069
# differential_evolution step 93: f(x)= -9.425296260835069
# differential_evolution step 94: f(x)= -9.425296260835069
# differential_evolution step 95: f(x)= -9.425296260835069
# differential_evolution step 96: f(x)= -9.425296260835069
# differential_evolution step 97: f(x)= -9.425296260835069
# differential_evolution step 98: f(x)= -9.425296260835069
# differential_evolution step 99: f(x)= -9.425296260835069
# differential_evolution step 100: f(x)= -9.425296260835069
# differential_evolution step 101: f(x)= -9.425296260835069
# differential_evolution step 102: f(x)= -9.425296260835069
# differential_evolution step 103: f(x)= -9.425296260835069
# differential_evolution step 104: f(x)= -9.425296260835069
# differential_evolution step 105: f(x)= -9.425296260835069
# differential_evolution step 106: f(x)= -9.425296260835069
# differential_evolution step 107: f(x)= -9.425296260835069
# differential_evolution step 108: f(x)= -9.425296260835069
# differential_evolution step 109: f(x)= -9.425296260835069
# differential_evolution step 110: f(x)= -9.425296260835069
# differential_evolution step 111: f(x)= -9.44225906762938
# differential_evolution step 112: f(x)= -9.44225906762938
# differential_evolution step 113: f(x)= -9.44225906762938
# differential_evolution step 114: f(x)= -9.44225906762938
# differential_evolution step 115: f(x)= -9.51339341185195
# differential_evolution step 116: f(x)= -9.51339341185195
# differential_evolution step 117: f(x)= -9.51339341185195
# differential_evolution step 118: f(x)= -9.51339341185195
# differential_evolution step 119: f(x)= -9.51339341185195
# differential_evolution step 120: f(x)= -9.51339341185195
# differential_evolution step 121: f(x)= -9.698035022927911
# differential_evolution step 122: f(x)= -9.698035022927911
# differential_evolution step 123: f(x)= -9.698035022927911
# differential_evolution step 124: f(x)= -9.698035022927911
# differential_evolution step 125: f(x)= -9.698035022927911
# differential_evolution step 126: f(x)= -9.698035022927911
# differential_evolution step 127: f(x)= -9.698035022927911
# differential_evolution step 128: f(x)= -9.698035022927911
# differential_evolution step 129: f(x)= -9.698035022927911
# differential_evolution step 130: f(x)= -9.698035022927911
# differential_evolution step 131: f(x)= -9.698035022927911
# differential_evolution step 132: f(x)= -9.698035022927911
# differential_evolution step 133: f(x)= -9.698035022927911
# differential_evolution step 134: f(x)= -9.698035022927911
# differential_evolution step 135: f(x)= -9.698035022927911
# differential_evolution step 136: f(x)= -9.698035022927911
# differential_evolution step 137: f(x)= -9.698035022927911
# differential_evolution step 138: f(x)= -9.698035022927911
# differential_evolution step 139: f(x)= -9.698035022927911
# differential_evolution step 140: f(x)= -9.698035022927911
# differential_evolution step 141: f(x)= -9.698035022927911
# differential_evolution step 142: f(x)= -9.698035022927911
# differential_evolution step 143: f(x)= -9.698035022927911
# differential_evolution step 144: f(x)= -9.775442333868796
# differential_evolution step 145: f(x)= -9.775442333868796
# differential_evolution step 146: f(x)= -9.775442333868796
# differential_evolution step 147: f(x)= -9.775442333868796
# differential_evolution step 148: f(x)= -9.775442333868796
# differential_evolution step 149: f(x)= -10.48816734427703
# differential_evolution step 150: f(x)= -10.48816734427703
# differential_evolution step 151: f(x)= -10.48816734427703
# differential_evolution step 152: f(x)= -10.48816734427703
# differential_evolution step 153: f(x)= -10.48816734427703
# differential_evolution step 154: f(x)= -10.48816734427703
# differential_evolution step 155: f(x)= -10.48816734427703
# differential_evolution step 156: f(x)= -10.48816734427703
# differential_evolution step 157: f(x)= -10.48816734427703
# differential_evolution step 158: f(x)= -10.48816734427703
# differential_evolution step 159: f(x)= -10.48816734427703
# differential_evolution step 160: f(x)= -10.48816734427703
# differential_evolution step 161: f(x)= -10.48816734427703
# differential_evolution step 162: f(x)= -10.48816734427703
# differential_evolution step 163: f(x)= -10.48816734427703
# differential_evolution step 164: f(x)= -10.729761906180556
# differential_evolution step 165: f(x)= -10.729761906180556
# differential_evolution step 166: f(x)= -10.729761906180556
# differential_evolution step 167: f(x)= -10.729761906180556
# differential_evolution step 168: f(x)= -10.729761906180556
# differential_evolution step 169: f(x)= -10.729761906180556
# differential_evolution step 170: f(x)= -10.729761906180556
# differential_evolution step 171: f(x)= -10.729761906180556
# differential_evolution step 172: f(x)= -10.729761906180556
# differential_evolution step 173: f(x)= -10.729761906180556
# differential_evolution step 174: f(x)= -10.729761906180556
# differential_evolution step 175: f(x)= -10.729761906180556
# differential_evolution step 176: f(x)= -10.729761906180556
# differential_evolution step 177: f(x)= -10.729761906180556
# differential_evolution step 178: f(x)= -10.729761906180556
# differential_evolution step 179: f(x)= -10.729761906180556
# differential_evolution step 180: f(x)= -10.729761906180556
# differential_evolution step 181: f(x)= -10.729761906180556
# differential_evolution step 182: f(x)= -10.729761906180556
# differential_evolution step 183: f(x)= -10.729761906180556
# differential_evolution step 184: f(x)= -10.729761906180556
# differential_evolution step 185: f(x)= -10.729761906180556
# differential_evolution step 186: f(x)= -10.729761906180556
# differential_evolution step 187: f(x)= -10.729761906180556
# differential_evolution step 188: f(x)= -10.729761906180556
# differential_evolution step 189: f(x)= -10.729761906180556
# differential_evolution step 190: f(x)= -10.729761906180556
# differential_evolution step 191: f(x)= -10.729761906180556
# differential_evolution step 192: f(x)= -10.729761906180556
# differential_evolution step 193: f(x)= -10.729761906180556
# differential_evolution step 194: f(x)= -10.729761906180556
# differential_evolution step 195: f(x)= -10.729761906180556
# differential_evolution step 196: f(x)= -10.729761906180556
# differential_evolution step 197: f(x)= -10.729761906180556
# differential_evolution step 198: f(x)= -10.729761906180556
# differential_evolution step 199: f(x)= -10.729761906180556
# differential_evolution step 200: f(x)= -10.729761906180556
# differential_evolution step 201: f(x)= -10.729761906180556
# differential_evolution step 202: f(x)= -10.729761906180556
# differential_evolution step 203: f(x)= -10.729761906180556
# differential_evolution step 204: f(x)= -10.729761906180556
# differential_evolution step 205: f(x)= -10.729761906180556
# differential_evolution step 206: f(x)= -10.729761906180556
# differential_evolution step 207: f(x)= -10.729761906180556
# differential_evolution step 208: f(x)= -10.729761906180556
# differential_evolution step 209: f(x)= -10.729761906180556
# differential_evolution step 210: f(x)= -10.729761906180556
# differential_evolution step 211: f(x)= -10.729761906180556
# differential_evolution step 212: f(x)= -10.729761906180556
# differential_evolution step 213: f(x)= -10.729761906180556
# differential_evolution step 214: f(x)= -10.729761906180556
# differential_evolution step 215: f(x)= -10.729761906180556
# differential_evolution step 216: f(x)= -10.729761906180556
# differential_evolution step 217: f(x)= -10.729761906180556
# differential_evolution step 218: f(x)= -10.729761906180556
# differential_evolution step 219: f(x)= -10.729761906180556
# differential_evolution step 220: f(x)= -10.729761906180556
# differential_evolution step 221: f(x)= -10.729761906180556
# differential_evolution step 222: f(x)= -10.729761906180556
# differential_evolution step 223: f(x)= -10.729761906180556
# differential_evolution step 224: f(x)= -10.729761906180556
# differential_evolution step 225: f(x)= -10.729761906180556
# differential_evolution step 226: f(x)= -10.729761906180556
# differential_evolution step 227: f(x)= -10.729761906180556
# differential_evolution step 228: f(x)= -10.729761906180556
# differential_evolution step 229: f(x)= -10.729761906180556
# differential_evolution step 230: f(x)= -10.729761906180556
# differential_evolution step 231: f(x)= -10.729761906180556
# differential_evolution step 232: f(x)= -10.729761906180556
# differential_evolution step 233: f(x)= -10.729761906180556
# differential_evolution step 234: f(x)= -11.050650326175457
# differential_evolution step 235: f(x)= -11.050650326175457
# differential_evolution step 236: f(x)= -11.050650326175457
# differential_evolution step 237: f(x)= -11.050650326175457
# differential_evolution step 238: f(x)= -11.050650326175457
# differential_evolution step 239: f(x)= -11.050650326175457
# differential_evolution step 240: f(x)= -11.050650326175457
# differential_evolution step 241: f(x)= -11.050650326175457
# differential_evolution step 242: f(x)= -11.050650326175457
# differential_evolution step 243: f(x)= -11.050650326175457
# differential_evolution step 244: f(x)= -11.050650326175457
# differential_evolution step 245: f(x)= -11.050650326175457
# differential_evolution step 246: f(x)= -11.050650326175457
# differential_evolution step 247: f(x)= -11.050650326175457
# differential_evolution step 248: f(x)= -11.050650326175457
# differential_evolution step 249: f(x)= -11.050650326175457
# differential_evolution step 250: f(x)= -11.050650326175457
# Polishing solution with 'L-BFGS-B'
# Iteration 2
# differential_evolution step 1: f(x)= -1.0610120468480773
# differential_evolution step 2: f(x)= -1.233430954264577
# differential_evolution step 3: f(x)= -1.4661578695668993
# differential_evolution step 4: f(x)= -1.5429660761792832
# differential_evolution step 5: f(x)= -1.7859277967981484
# differential_evolution step 6: f(x)= -1.8219350464397053
# differential_evolution step 7: f(x)= -1.8219350464397053
# differential_evolution step 8: f(x)= -1.8219350464397053
# differential_evolution step 9: f(x)= -1.8219350464397053
# differential_evolution step 10: f(x)= -1.8219350464397053
# differential_evolution step 11: f(x)= -2.3961287494947783
# differential_evolution step 12: f(x)= -2.3961287494947783
# differential_evolution step 13: f(x)= -2.3961287494947783
# differential_evolution step 14: f(x)= -2.3961287494947783
# differential_evolution step 15: f(x)= -2.3961287494947783
# differential_evolution step 16: f(x)= -2.3961287494947783
# differential_evolution step 17: f(x)= -2.3961287494947783
# differential_evolution step 18: f(x)= -2.3961287494947783
# differential_evolution step 19: f(x)= -2.3961287494947783
# differential_evolution step 20: f(x)= -2.3961287494947783
# differential_evolution step 21: f(x)= -2.3961287494947783
# differential_evolution step 22: f(x)= -2.3961287494947783
# differential_evolution step 23: f(x)= -2.3961287494947783
# differential_evolution step 24: f(x)= -2.3961287494947783
# differential_evolution step 25: f(x)= -2.3961287494947783
# differential_evolution step 26: f(x)= -2.3961287494947783
# differential_evolution step 27: f(x)= -2.3961287494947783
# differential_evolution step 28: f(x)= -2.3961287494947783
# differential_evolution step 29: f(x)= -2.3961287494947783
# differential_evolution step 30: f(x)= -2.3961287494947783
# differential_evolution step 31: f(x)= -2.3961287494947783
# differential_evolution step 32: f(x)= -2.3961287494947783
# differential_evolution step 33: f(x)= -2.3961287494947783
# differential_evolution step 34: f(x)= -2.3961287494947783
# differential_evolution step 35: f(x)= -2.5006842754075933
# differential_evolution step 36: f(x)= -2.7055319060804095
# differential_evolution step 37: f(x)= -2.7055319060804095
# differential_evolution step 38: f(x)= -2.7055319060804095
# differential_evolution step 39: f(x)= -2.7055319060804095
# differential_evolution step 40: f(x)= -2.7055319060804095
# differential_evolution step 41: f(x)= -2.7055319060804095
# differential_evolution step 42: f(x)= -2.7055319060804095
# differential_evolution step 43: f(x)= -2.7055319060804095
# differential_evolution step 44: f(x)= -2.7697208458176874
# differential_evolution step 45: f(x)= -2.7697208458176874
# differential_evolution step 46: f(x)= -2.8180184128108863
# differential_evolution step 47: f(x)= -2.8180184128108863
# differential_evolution step 48: f(x)= -2.8180184128108863
# differential_evolution step 49: f(x)= -2.8238313323776936
# differential_evolution step 50: f(x)= -2.8238313323776936
# differential_evolution step 51: f(x)= -2.8238313323776936
# differential_evolution step 52: f(x)= -2.860518049906716
# differential_evolution step 53: f(x)= -2.860518049906716
# differential_evolution step 54: f(x)= -2.860518049906716
# differential_evolution step 55: f(x)= -2.8976263092374097
# differential_evolution step 56: f(x)= -2.8976263092374097
# differential_evolution step 57: f(x)= -3.071881297844641
# differential_evolution step 58: f(x)= -3.071881297844641
# differential_evolution step 59: f(x)= -3.071881297844641
# differential_evolution step 60: f(x)= -3.071881297844641
# differential_evolution step 61: f(x)= -3.071881297844641
# differential_evolution step 62: f(x)= -3.071881297844641
# differential_evolution step 63: f(x)= -3.071881297844641
# differential_evolution step 64: f(x)= -3.071881297844641
# differential_evolution step 65: f(x)= -3.071881297844641
# differential_evolution step 66: f(x)= -3.071881297844641
# differential_evolution step 67: f(x)= -3.1224341407969405
# differential_evolution step 68: f(x)= -3.1224341407969405
# differential_evolution step 69: f(x)= -3.1224341407969405
# differential_evolution step 70: f(x)= -3.1224341407969405
# differential_evolution step 71: f(x)= -3.1224341407969405
# differential_evolution step 72: f(x)= -3.1224341407969405
# differential_evolution step 73: f(x)= -3.1224341407969405
# differential_evolution step 74: f(x)= -3.1224341407969405
# differential_evolution step 75: f(x)= -3.1224341407969405
# differential_evolution step 76: f(x)= -3.1224341407969405
# differential_evolution step 77: f(x)= -3.1224341407969405
# differential_evolution step 78: f(x)= -3.1224341407969405
# differential_evolution step 79: f(x)= -3.1224341407969405
# differential_evolution step 80: f(x)= -3.1224341407969405
# differential_evolution step 81: f(x)= -3.1224341407969405
# differential_evolution step 82: f(x)= -3.135215716875166
# differential_evolution step 83: f(x)= -3.1477440886185946
# differential_evolution step 84: f(x)= -3.1477440886185946
# differential_evolution step 85: f(x)= -3.1477440886185946
# differential_evolution step 86: f(x)= -3.1477440886185946
# differential_evolution step 87: f(x)= -3.1477440886185946
# differential_evolution step 88: f(x)= -3.1477440886185946
# differential_evolution step 89: f(x)= -3.1477440886185946
# differential_evolution step 90: f(x)= -3.1884453446432417
# differential_evolution step 91: f(x)= -3.1884453446432417
# differential_evolution step 92: f(x)= -3.1884453446432417
# differential_evolution step 93: f(x)= -3.1884453446432417
# differential_evolution step 94: f(x)= -3.1884453446432417
# differential_evolution step 95: f(x)= -3.2251865544150746
# differential_evolution step 96: f(x)= -3.2251865544150746
# differential_evolution step 97: f(x)= -3.2251865544150746
# differential_evolution step 98: f(x)= -3.234886667054866
# differential_evolution step 99: f(x)= -3.234886667054866
# differential_evolution step 100: f(x)= -3.234886667054866
# differential_evolution step 101: f(x)= -3.234886667054866
# differential_evolution step 102: f(x)= -3.234886667054866
# differential_evolution step 103: f(x)= -3.234886667054866
# differential_evolution step 104: f(x)= -3.2730204357820583
# differential_evolution step 105: f(x)= -3.2730204357820583
# differential_evolution step 106: f(x)= -3.2730204357820583
# differential_evolution step 107: f(x)= -3.2730204357820583
# differential_evolution step 108: f(x)= -3.2730204357820583
# differential_evolution step 109: f(x)= -3.2730204357820583
# differential_evolution step 110: f(x)= -3.2730204357820583
# differential_evolution step 111: f(x)= -3.2730204357820583
# differential_evolution step 112: f(x)= -3.2730204357820583
# differential_evolution step 113: f(x)= -3.2730204357820583
# differential_evolution step 114: f(x)= -3.2730204357820583
# differential_evolution step 115: f(x)= -3.2730204357820583
# differential_evolution step 116: f(x)= -3.2730204357820583
# differential_evolution step 117: f(x)= -3.2730204357820583
# differential_evolution step 118: f(x)= -3.2730204357820583
# differential_evolution step 119: f(x)= -3.2730204357820583
# differential_evolution step 120: f(x)= -3.2730204357820583
# differential_evolution step 121: f(x)= -3.2730204357820583
# differential_evolution step 122: f(x)= -3.3963117392972038
# differential_evolution step 123: f(x)= -3.3963117392972038
# differential_evolution step 124: f(x)= -3.3963117392972038
# differential_evolution step 125: f(x)= -3.3963117392972038
# differential_evolution step 126: f(x)= -3.410786137607147
# differential_evolution step 127: f(x)= -3.410786137607147
# differential_evolution step 128: f(x)= -3.410786137607147
# differential_evolution step 129: f(x)= -3.5210528792636637
# differential_evolution step 130: f(x)= -3.5210528792636637
# differential_evolution step 131: f(x)= -3.5210528792636637
# differential_evolution step 132: f(x)= -3.5210528792636637
# differential_evolution step 133: f(x)= -3.5210528792636637
# differential_evolution step 134: f(x)= -3.5210528792636637
# differential_evolution step 135: f(x)= -3.5210528792636637
# differential_evolution step 136: f(x)= -3.5210528792636637
# differential_evolution step 137: f(x)= -3.5210528792636637
# differential_evolution step 138: f(x)= -3.5210528792636637
# differential_evolution step 139: f(x)= -3.5210528792636637
# differential_evolution step 140: f(x)= -3.671204285959959
# differential_evolution step 141: f(x)= -3.671204285959959
# differential_evolution step 142: f(x)= -3.671204285959959
# differential_evolution step 143: f(x)= -3.671204285959959
# differential_evolution step 144: f(x)= -3.671204285959959
# differential_evolution step 145: f(x)= -3.671204285959959
# differential_evolution step 146: f(x)= -3.671204285959959
# differential_evolution step 147: f(x)= -3.671204285959959
# differential_evolution step 148: f(x)= -3.671204285959959
# differential_evolution step 149: f(x)= -3.671204285959959
# differential_evolution step 150: f(x)= -3.671204285959959
# differential_evolution step 151: f(x)= -3.731153927718651
# differential_evolution step 152: f(x)= -3.731153927718651
# differential_evolution step 153: f(x)= -3.731153927718651
# differential_evolution step 154: f(x)= -3.731153927718651
# differential_evolution step 155: f(x)= -3.731153927718651
# differential_evolution step 156: f(x)= -3.731153927718651
# differential_evolution step 157: f(x)= -3.731153927718651
# differential_evolution step 158: f(x)= -3.731153927718651
# differential_evolution step 159: f(x)= -3.731153927718651
# differential_evolution step 160: f(x)= -3.731153927718651
# differential_evolution step 161: f(x)= -3.731153927718651
# differential_evolution step 162: f(x)= -3.731153927718651
# differential_evolution step 163: f(x)= -3.731153927718651
# differential_evolution step 164: f(x)= -3.731153927718651
# differential_evolution step 165: f(x)= -3.731153927718651
# differential_evolution step 166: f(x)= -3.731153927718651
# differential_evolution step 167: f(x)= -3.731153927718651
# differential_evolution step 168: f(x)= -3.731153927718651
# differential_evolution step 169: f(x)= -3.731153927718651
# differential_evolution step 170: f(x)= -3.731153927718651
# differential_evolution step 171: f(x)= -3.731153927718651
# differential_evolution step 172: f(x)= -3.731153927718651
# differential_evolution step 173: f(x)= -3.731153927718651
# differential_evolution step 174: f(x)= -3.9433715663927558
# differential_evolution step 175: f(x)= -3.9433715663927558
# differential_evolution step 176: f(x)= -3.9433715663927558
# differential_evolution step 177: f(x)= -3.9433715663927558
# differential_evolution step 178: f(x)= -3.9433715663927558
# differential_evolution step 179: f(x)= -3.9433715663927558
# differential_evolution step 180: f(x)= -3.9433715663927558
# differential_evolution step 181: f(x)= -3.9433715663927558
# differential_evolution step 182: f(x)= -3.9433715663927558
# differential_evolution step 183: f(x)= -3.9433715663927558
# differential_evolution step 184: f(x)= -3.9433715663927558
# differential_evolution step 185: f(x)= -3.9433715663927558
# differential_evolution step 186: f(x)= -3.9433715663927558
# differential_evolution step 187: f(x)= -3.9433715663927558
# differential_evolution step 188: f(x)= -3.961142513946129
# differential_evolution step 189: f(x)= -4.178695231889662
# differential_evolution step 190: f(x)= -4.178695231889662
# differential_evolution step 191: f(x)= -4.178695231889662
# differential_evolution step 192: f(x)= -4.178695231889662
# differential_evolution step 193: f(x)= -4.178695231889662
# differential_evolution step 194: f(x)= -4.178695231889662
# differential_evolution step 195: f(x)= -4.178695231889662
# differential_evolution step 196: f(x)= -4.178695231889662
# differential_evolution step 197: f(x)= -4.178695231889662
# differential_evolution step 198: f(x)= -4.178695231889662
# differential_evolution step 199: f(x)= -4.178695231889662
# differential_evolution step 200: f(x)= -4.178695231889662
# differential_evolution step 201: f(x)= -4.178695231889662
# differential_evolution step 202: f(x)= -4.296850836898614
# differential_evolution step 203: f(x)= -4.296850836898614
# differential_evolution step 204: f(x)= -4.296850836898614
# differential_evolution step 205: f(x)= -4.296850836898614
# differential_evolution step 206: f(x)= -4.296850836898614
# differential_evolution step 207: f(x)= -4.296850836898614
# differential_evolution step 208: f(x)= -4.296850836898614
# differential_evolution step 209: f(x)= -4.296850836898614
# differential_evolution step 210: f(x)= -4.296850836898614
# differential_evolution step 211: f(x)= -4.296850836898614
# differential_evolution step 212: f(x)= -4.296850836898614
# differential_evolution step 213: f(x)= -4.296850836898614
# differential_evolution step 214: f(x)= -4.296850836898614
# differential_evolution step 215: f(x)= -4.296850836898614
# differential_evolution step 216: f(x)= -4.296850836898614
# differential_evolution step 217: f(x)= -4.296850836898614
# differential_evolution step 218: f(x)= -4.296850836898614
# differential_evolution step 219: f(x)= -4.296850836898614
# differential_evolution step 220: f(x)= -4.296850836898614
# differential_evolution step 221: f(x)= -4.296850836898614
# differential_evolution step 222: f(x)= -4.296850836898614
# differential_evolution step 223: f(x)= -4.296850836898614
# differential_evolution step 224: f(x)= -4.296850836898614
# differential_evolution step 225: f(x)= -4.296850836898614
# differential_evolution step 226: f(x)= -4.296850836898614
# differential_evolution step 227: f(x)= -4.296850836898614
# differential_evolution step 228: f(x)= -4.296850836898614
# differential_evolution step 229: f(x)= -4.296850836898614
# differential_evolution step 230: f(x)= -4.296850836898614
# differential_evolution step 231: f(x)= -4.296850836898614
# differential_evolution step 232: f(x)= -4.296850836898614
# differential_evolution step 233: f(x)= -4.296850836898614
# differential_evolution step 234: f(x)= -4.296850836898614
# differential_evolution step 235: f(x)= -4.296850836898614
# differential_evolution step 236: f(x)= -4.296850836898614
# differential_evolution step 237: f(x)= -4.296850836898614
# differential_evolution step 238: f(x)= -4.296850836898614
# differential_evolution step 239: f(x)= -4.296850836898614
# differential_evolution step 240: f(x)= -4.605757279429781
# differential_evolution step 241: f(x)= -4.605757279429781
# differential_evolution step 242: f(x)= -4.605757279429781
# differential_evolution step 243: f(x)= -4.605757279429781
# differential_evolution step 244: f(x)= -4.605757279429781
# differential_evolution step 245: f(x)= -4.605757279429781
# differential_evolution step 246: f(x)= -4.695521859901021
# differential_evolution step 247: f(x)= -4.695521859901021
# differential_evolution step 248: f(x)= -4.695521859901021
# differential_evolution step 249: f(x)= -4.695521859901021
# differential_evolution step 250: f(x)= -4.695521859901021
# Polishing solution with 'L-BFGS-B'
# Iteration 3
# differential_evolution step 1: f(x)= -1.23314964027918
# differential_evolution step 2: f(x)= -1.4377376290883603
# differential_evolution step 3: f(x)= -1.7350779830435954
# differential_evolution step 4: f(x)= -1.7488461116342933
# differential_evolution step 5: f(x)= -1.7488461116342933
# differential_evolution step 6: f(x)= -1.7488461116342933
# differential_evolution step 7: f(x)= -1.8114343039751475
# differential_evolution step 8: f(x)= -1.8225739487539272
# differential_evolution step 9: f(x)= -1.9319807446501613
# differential_evolution step 10: f(x)= -1.9319807446501613
# differential_evolution step 11: f(x)= -1.9935119078613752
# differential_evolution step 12: f(x)= -1.9935119078613752
# differential_evolution step 13: f(x)= -1.9935119078613752
# differential_evolution step 14: f(x)= -1.9935119078613752
# differential_evolution step 15: f(x)= -2.0437008175284745
# differential_evolution step 16: f(x)= -2.2151256485587396
# differential_evolution step 17: f(x)= -2.2151256485587396
# differential_evolution step 18: f(x)= -2.2151256485587396
# differential_evolution step 19: f(x)= -2.2151256485587396
# differential_evolution step 20: f(x)= -2.2151256485587396
# differential_evolution step 21: f(x)= -2.2151256485587396
# differential_evolution step 22: f(x)= -2.223244015153341
# differential_evolution step 23: f(x)= -2.3393555852551913
# differential_evolution step 24: f(x)= -2.3393555852551913
# differential_evolution step 25: f(x)= -2.3393555852551913
# differential_evolution step 26: f(x)= -2.3393555852551913
# differential_evolution step 27: f(x)= -2.3393555852551913
# differential_evolution step 28: f(x)= -2.3393555852551913
# differential_evolution step 29: f(x)= -2.3846819461703035
# differential_evolution step 30: f(x)= -2.4739068729074916
# differential_evolution step 31: f(x)= -2.4739068729074916
# differential_evolution step 32: f(x)= -2.4739068729074916
# differential_evolution step 33: f(x)= -2.4739068729074916
# differential_evolution step 34: f(x)= -2.4739068729074916
# differential_evolution step 35: f(x)= -2.4739068729074916
# differential_evolution step 36: f(x)= -2.4739068729074916
# differential_evolution step 37: f(x)= -2.4739068729074916
# differential_evolution step 38: f(x)= -2.649198660662421
# differential_evolution step 39: f(x)= -2.649198660662421
# differential_evolution step 40: f(x)= -2.649198660662421
# differential_evolution step 41: f(x)= -2.7745436464098248
# differential_evolution step 42: f(x)= -2.7745436464098248
# differential_evolution step 43: f(x)= -2.7745436464098248
# differential_evolution step 44: f(x)= -2.7745436464098248
# differential_evolution step 45: f(x)= -2.7745436464098248
# differential_evolution step 46: f(x)= -2.7745436464098248
# differential_evolution step 47: f(x)= -2.7745436464098248
# differential_evolution step 48: f(x)= -2.7745436464098248
# differential_evolution step 49: f(x)= -2.7745436464098248
# differential_evolution step 50: f(x)= -2.7745436464098248
# differential_evolution step 51: f(x)= -2.7745436464098248
# differential_evolution step 52: f(x)= -2.7745436464098248
# differential_evolution step 53: f(x)= -2.7745436464098248
# differential_evolution step 54: f(x)= -2.7745436464098248
# differential_evolution step 55: f(x)= -2.7745436464098248
# differential_evolution step 56: f(x)= -2.7745436464098248
# differential_evolution step 57: f(x)= -2.7745436464098248
# differential_evolution step 58: f(x)= -2.7745436464098248
# differential_evolution step 59: f(x)= -2.7745436464098248
# differential_evolution step 60: f(x)= -2.7745436464098248
# differential_evolution step 61: f(x)= -3.025348758035591
# differential_evolution step 62: f(x)= -3.025348758035591
# differential_evolution step 63: f(x)= -3.025348758035591
# differential_evolution step 64: f(x)= -3.025348758035591
# differential_evolution step 65: f(x)= -3.025348758035591
# differential_evolution step 66: f(x)= -3.025348758035591
# differential_evolution step 67: f(x)= -3.025348758035591
# differential_evolution step 68: f(x)= -3.025348758035591
# differential_evolution step 69: f(x)= -3.025348758035591
# differential_evolution step 70: f(x)= -3.025348758035591
# differential_evolution step 71: f(x)= -3.025348758035591
# differential_evolution step 72: f(x)= -3.025348758035591
# differential_evolution step 73: f(x)= -3.025348758035591
# differential_evolution step 74: f(x)= -3.0626791039208
# ...
# differential_evolution step 241: f(x)= -1.859567139105934
# differential_evolution step 242: f(x)= -1.859567139105934
# differential_evolution step 243: f(x)= -1.859567139105934
# differential_evolution step 244: f(x)= -1.859567139105934
# differential_evolution step 245: f(x)= -1.8629390873693978
# differential_evolution step 246: f(x)= -1.8629390873693978
# differential_evolution step 247: f(x)= -1.903954750129742
# differential_evolution step 248: f(x)= -1.903954750129742
# differential_evolution step 249: f(x)= -1.903954750129742
# differential_evolution step 250: f(x)= -1.903954750129742
# Polishing solution with 'L-BFGS-B'
# Iteration 6
# differential_evolution step 1: f(x)= -0.06847886268604952
# differential_evolution step 2: f(x)= -0.06847886268604952
# differential_evolution step 3: f(x)= -0.09611974829471137
# differential_evolution step 4: f(x)= -0.09611974829471137
# differential_evolution step 5: f(x)= -0.09611974829471137
# differential_evolution step 6: f(x)= -0.09611974829471137
# differential_evolution step 7: f(x)= -0.09611974829471137
# differential_evolution step 8: f(x)= -0.09611974829471137
# differential_evolution step 9: f(x)= -0.09611974829471137
# differential_evolution step 10: f(x)= -0.10590296837304436
# differential_evolution step 11: f(x)= -0.10590296837304436
# differential_evolution step 12: f(x)= -0.10590296837304436
# differential_evolution step 13: f(x)= -0.10590296837304436
# differential_evolution step 14: f(x)= -0.10590296837304436
# differential_evolution step 15: f(x)= -0.11067843395107957
# differential_evolution step 16: f(x)= -0.11067843395107957
# differential_evolution step 17: f(x)= -0.11067843395107957
# differential_evolution step 18: f(x)= -0.11441162029041152
# differential_evolution step 19: f(x)= -0.11441162029041152
# differential_evolution step 20: f(x)= -0.11441162029041152
# differential_evolution step 21: f(x)= -0.11441162029041152
# differential_evolution step 22: f(x)= -0.11863460562651085
# differential_evolution step 23: f(x)= -0.11863460562651085
# differential_evolution step 24: f(x)= -0.1210551728023006
# differential_evolution step 25: f(x)= -0.1210551728023006
# differential_evolution step 26: f(x)= -0.13664269473264312
# differential_evolution step 27: f(x)= -0.13664269473264312
# differential_evolution step 28: f(x)= -0.13820892269666274
# differential_evolution step 29: f(x)= -0.13820892269666274
# differential_evolution step 30: f(x)= -0.13820892269666274
# differential_evolution step 31: f(x)= -0.13820892269666274
# differential_evolution step 32: f(x)= -0.13820892269666274
# differential_evolution step 33: f(x)= -0.16961130774564026
# differential_evolution step 34: f(x)= -0.16961130774564026
# differential_evolution step 35: f(x)= -0.16961130774564026
# differential_evolution step 36: f(x)= -0.16961130774564026
# differential_evolution step 37: f(x)= -0.16961130774564026
# differential_evolution step 38: f(x)= -0.16961130774564026
# differential_evolution step 39: f(x)= -0.16961130774564026
# differential_evolution step 40: f(x)= -0.16961130774564026
# differential_evolution step 41: f(x)= -0.16961130774564026
# differential_evolution step 42: f(x)= -0.16961130774564026
# differential_evolution step 43: f(x)= -0.16961130774564026
# differential_evolution step 44: f(x)= -0.16961130774564026
# differential_evolution step 45: f(x)= -0.16961130774564026
# differential_evolution step 46: f(x)= -0.16961130774564026
# differential_evolution step 47: f(x)= -0.16961130774564026
# differential_evolution step 48: f(x)= -0.16961130774564026
# differential_evolution step 49: f(x)= -0.16961130774564026
# differential_evolution step 50: f(x)= -0.16961130774564026
# differential_evolution step 51: f(x)= -0.16961130774564026
# differential_evolution step 52: f(x)= -0.16961130774564026
# differential_evolution step 53: f(x)= -0.16961130774564026
# differential_evolution step 54: f(x)= -0.16961130774564026
# differential_evolution step 55: f(x)= -0.16961130774564026
# differential_evolution step 56: f(x)= -0.16961130774564026
# differential_evolution step 57: f(x)= -0.16961130774564026
# differential_evolution step 58: f(x)= -0.16961130774564026
# differential_evolution step 59: f(x)= -0.16961130774564026
# differential_evolution step 60: f(x)= -0.16961130774564026
# differential_evolution step 61: f(x)= -0.16961130774564026
# differential_evolution step 62: f(x)= -0.16961130774564026
# differential_evolution step 63: f(x)= -0.16961130774564026
# differential_evolution step 64: f(x)= -0.16961130774564026
# differential_evolution step 65: f(x)= -0.17023215988228912
# differential_evolution step 66: f(x)= -0.17023215988228912
# differential_evolution step 67: f(x)= -0.17314114366303102
# differential_evolution step 68: f(x)= -0.17314114366303102
# differential_evolution step 69: f(x)= -0.17314114366303102
# differential_evolution step 70: f(x)= -0.17314114366303102
# differential_evolution step 71: f(x)= -0.19139520344702987
# differential_evolution step 72: f(x)= -0.19139520344702987
# differential_evolution step 73: f(x)= -0.19139520344702987
# differential_evolution step 74: f(x)= -0.19139520344702987
# differential_evolution step 75: f(x)= -0.19139520344702987
# differential_evolution step 76: f(x)= -0.19139520344702987
# differential_evolution step 77: f(x)= -0.19139520344702987
# differential_evolution step 78: f(x)= -0.19139520344702987
# differential_evolution step 79: f(x)= -0.19139520344702987
# differential_evolution step 80: f(x)= -0.19139520344702987
# differential_evolution step 81: f(x)= -0.19139520344702987
# differential_evolution step 82: f(x)= -0.19139520344702987
# differential_evolution step 83: f(x)= -0.19139520344702987
# differential_evolution step 84: f(x)= -0.19139520344702987
# differential_evolution step 85: f(x)= -0.19139520344702987
# differential_evolution step 86: f(x)= -0.19139520344702987
# differential_evolution step 87: f(x)= -0.19139520344702987
# differential_evolution step 88: f(x)= -0.19139520344702987
# differential_evolution step 89: f(x)= -0.19139520344702987
# differential_evolution step 90: f(x)= -0.19342861741296247
# differential_evolution step 91: f(x)= -0.19342861741296247
# differential_evolution step 92: f(x)= -0.19342861741296247
# differential_evolution step 93: f(x)= -0.19342861741296247
# differential_evolution step 94: f(x)= -0.19342861741296247
# differential_evolution step 95: f(x)= -0.19342861741296247
# differential_evolution step 96: f(x)= -0.19342861741296247
# differential_evolution step 97: f(x)= -0.19342861741296247
# differential_evolution step 98: f(x)= -0.19342861741296247
# differential_evolution step 99: f(x)= -0.19342861741296247
# differential_evolution step 100: f(x)= -0.19342861741296247
# differential_evolution step 101: f(x)= -0.19342861741296247
# differential_evolution step 102: f(x)= -0.19342861741296247
# differential_evolution step 103: f(x)= -0.19342861741296247
# differential_evolution step 104: f(x)= -0.19342861741296247
# differential_evolution step 105: f(x)= -0.19342861741296247
# differential_evolution step 106: f(x)= -0.19342861741296247
# differential_evolution step 107: f(x)= -0.19342861741296247
# differential_evolution step 108: f(x)= -0.1948118472203646
# differential_evolution step 109: f(x)= -0.19744438607244774
# differential_evolution step 110: f(x)= -0.19744438607244774
# differential_evolution step 111: f(x)= -0.19744438607244774
# differential_evolution step 112: f(x)= -0.19744438607244774
# differential_evolution step 113: f(x)= -0.19744438607244774
# differential_evolution step 114: f(x)= -0.19744438607244774
# differential_evolution step 115: f(x)= -0.1990830451869101
# differential_evolution step 116: f(x)= -0.1990830451869101
# differential_evolution step 117: f(x)= -0.1990830451869101
# differential_evolution step 118: f(x)= -0.1990830451869101
# differential_evolution step 119: f(x)= -0.1990830451869101
# differential_evolution step 120: f(x)= -0.20708483309743997
# differential_evolution step 121: f(x)= -0.20708483309743997
# differential_evolution step 122: f(x)= -0.20708483309743997
# differential_evolution step 123: f(x)= -0.20708483309743997
# differential_evolution step 124: f(x)= -0.20708483309743997
# differential_evolution step 125: f(x)= -0.20708483309743997
# differential_evolution step 126: f(x)= -0.20708483309743997
# differential_evolution step 127: f(x)= -0.20708483309743997
# differential_evolution step 128: f(x)= -0.20708483309743997
# differential_evolution step 129: f(x)= -0.20708483309743997
# differential_evolution step 130: f(x)= -0.20708483309743997
# differential_evolution step 131: f(x)= -0.20708483309743997
# differential_evolution step 132: f(x)= -0.20708483309743997
# differential_evolution step 133: f(x)= -0.20708483309743997
# differential_evolution step 134: f(x)= -0.20708483309743997
# differential_evolution step 135: f(x)= -0.20708483309743997
# differential_evolution step 136: f(x)= -0.20708483309743997
# differential_evolution step 137: f(x)= -0.20708483309743997
# differential_evolution step 138: f(x)= -0.20708483309743997
# differential_evolution step 139: f(x)= -0.20708483309743997
# differential_evolution step 140: f(x)= -0.20708483309743997
# differential_evolution step 141: f(x)= -0.20708483309743997
# differential_evolution step 142: f(x)= -0.20708483309743997
# differential_evolution step 143: f(x)= -0.20708483309743997
# differential_evolution step 144: f(x)= -0.20888782901153036
# differential_evolution step 145: f(x)= -0.20888782901153036
# differential_evolution step 146: f(x)= -0.20888782901153036
# differential_evolution step 147: f(x)= -0.20888782901153036
# differential_evolution step 148: f(x)= -0.20888782901153036
# differential_evolution step 149: f(x)= -0.20888782901153036
# differential_evolution step 150: f(x)= -0.20888782901153036
# differential_evolution step 151: f(x)= -0.21038346756753867
# differential_evolution step 152: f(x)= -0.21393858285941292
# differential_evolution step 153: f(x)= -0.21393858285941292
# differential_evolution step 154: f(x)= -0.21393858285941292
# differential_evolution step 155: f(x)= -0.21393858285941292
# differential_evolution step 156: f(x)= -0.21393858285941292
# differential_evolution step 157: f(x)= -0.21393858285941292
# differential_evolution step 158: f(x)= -0.21393858285941292
# differential_evolution step 159: f(x)= -0.21393858285941292
# differential_evolution step 160: f(x)= -0.21393858285941292
# differential_evolution step 161: f(x)= -0.21459084778226156
# differential_evolution step 162: f(x)= -0.21745551617823367
# differential_evolution step 163: f(x)= -0.21745551617823367
# differential_evolution step 164: f(x)= -0.21745551617823367
# differential_evolution step 165: f(x)= -0.21745551617823367
# differential_evolution step 166: f(x)= -0.21745551617823367
# differential_evolution step 167: f(x)= -0.22286790630471387
# differential_evolution step 168: f(x)= -0.22286790630471387
# differential_evolution step 169: f(x)= -0.22286790630471387
# differential_evolution step 170: f(x)= -0.22286790630471387
# differential_evolution step 171: f(x)= -0.22286790630471387
# differential_evolution step 172: f(x)= -0.22286790630471387
# differential_evolution step 173: f(x)= -0.22286790630471387
# differential_evolution step 174: f(x)= -0.22286790630471387
# differential_evolution step 175: f(x)= -0.22286790630471387
# differential_evolution step 176: f(x)= -0.22286790630471387
# differential_evolution step 177: f(x)= -0.22286790630471387
# differential_evolution step 178: f(x)= -0.22286790630471387
# differential_evolution step 179: f(x)= -0.22286790630471387
# differential_evolution step 180: f(x)= -0.22286790630471387
# differential_evolution step 181: f(x)= -0.22286790630471387
# differential_evolution step 182: f(x)= -0.22286790630471387
# differential_evolution step 183: f(x)= -0.22286790630471387
# differential_evolution step 184: f(x)= -0.22286790630471387
# differential_evolution step 185: f(x)= -0.22286790630471387
# differential_evolution step 186: f(x)= -0.22286790630471387
# differential_evolution step 187: f(x)= -0.22286790630471387
# differential_evolution step 188: f(x)= -0.22286790630471387
# differential_evolution step 189: f(x)= -0.22286790630471387
# differential_evolution step 190: f(x)= -0.22286790630471387
# differential_evolution step 191: f(x)= -0.22286790630471387
# differential_evolution step 192: f(x)= -0.22506707036473017
# differential_evolution step 193: f(x)= -0.22506707036473017
# differential_evolution step 194: f(x)= -0.22506707036473017
# differential_evolution step 195: f(x)= -0.22506707036473017
# differential_evolution step 196: f(x)= -0.22506707036473017
# differential_evolution step 197: f(x)= -0.22506707036473017
# differential_evolution step 198: f(x)= -0.22506707036473017
# differential_evolution step 199: f(x)= -0.22506707036473017
# differential_evolution step 200: f(x)= -0.22506707036473017
# differential_evolution step 201: f(x)= -0.22554846153911967
# differential_evolution step 202: f(x)= -0.22554846153911967
# differential_evolution step 203: f(x)= -0.22554846153911967
# differential_evolution step 204: f(x)= -0.22554846153911967
# differential_evolution step 205: f(x)= -0.22554846153911967
# differential_evolution step 206: f(x)= -0.22554846153911967
# differential_evolution step 207: f(x)= -0.22554846153911967
# differential_evolution step 208: f(x)= -0.22554846153911967
# differential_evolution step 209: f(x)= -0.22554846153911967
# differential_evolution step 210: f(x)= -0.22554846153911967
# differential_evolution step 211: f(x)= -0.22554846153911967
# differential_evolution step 212: f(x)= -0.22554846153911967
# differential_evolution step 213: f(x)= -0.22554846153911967
# differential_evolution step 214: f(x)= -0.22554846153911967
# differential_evolution step 215: f(x)= -0.22554846153911967
# differential_evolution step 216: f(x)= -0.22554846153911967
# differential_evolution step 217: f(x)= -0.22554846153911967
# differential_evolution step 218: f(x)= -0.22554846153911967
# differential_evolution step 219: f(x)= -0.22554846153911967
# differential_evolution step 220: f(x)= -0.22554846153911967
# differential_evolution step 221: f(x)= -0.22554846153911967
# differential_evolution step 222: f(x)= -0.22554846153911967
# differential_evolution step 223: f(x)= -0.22554846153911967
# differential_evolution step 224: f(x)= -0.22554846153911967
# differential_evolution step 225: f(x)= -0.22554846153911967
# differential_evolution step 226: f(x)= -0.22554846153911967
# differential_evolution step 227: f(x)= -0.22554846153911967
# differential_evolution step 228: f(x)= -0.22554846153911967
# differential_evolution step 229: f(x)= -0.22554846153911967
# differential_evolution step 230: f(x)= -0.22554846153911967
# differential_evolution step 231: f(x)= -0.22554846153911967
# differential_evolution step 232: f(x)= -0.22554846153911967
# differential_evolution step 233: f(x)= -0.22554846153911967
# differential_evolution step 234: f(x)= -0.22554846153911967
# differential_evolution step 235: f(x)= -0.22554846153911967
# differential_evolution step 236: f(x)= -0.22554846153911967
# differential_evolution step 237: f(x)= -0.22554846153911967
# differential_evolution step 238: f(x)= -0.22554846153911967
# differential_evolution step 239: f(x)= -0.22554846153911967
# differential_evolution step 240: f(x)= -0.22554846153911967
# differential_evolution step 241: f(x)= -0.22554846153911967
# differential_evolution step 242: f(x)= -0.22554846153911967
# differential_evolution step 243: f(x)= -0.22728677695999977
# differential_evolution step 244: f(x)= -0.22728677695999977
# differential_evolution step 245: f(x)= -0.22728677695999977
# differential_evolution step 246: f(x)= -0.22728677695999977
# differential_evolution step 247: f(x)= -0.22728677695999977
# differential_evolution step 248: f(x)= -0.22728677695999977
# differential_evolution step 249: f(x)= -0.22728677695999977
# differential_evolution step 250: f(x)= -0.22728677695999977
# Polishing solution with 'L-BFGS-B'
# Iteration 7
# differential_evolution step 1: f(x)= 0.0
# Polishing solution with 'L-BFGS-B'
# K: 1
# Approximation: 0.34730538922155685
# K: 2
# Approximation: 0.6407185628742514
# K: 3
# Approximation: 0.6407185628742514
# K: 4
# Approximation: 0.6407185628742514
# K: 5
# Approximation: 0.6407185628742514
# K: 6
# Approximation: 0.6407185628742514
# K: 7
# Approximation: 0.6407185628742514
# K: 8
# Approximation: 0.6407185628742514
# K: 9
# Approximation: 0.6407185628742514

# %%
gpi_results
# Out:
#   approximation
# K
# 1      0.347305
# 2      0.640719
# 3      0.640719
# 4      0.640719
# 5      0.640719
# 6      0.640719
# 7      0.640719
# 8      0.640719
# 9      0.640719

# %%
gpi_results.to_csv('../../data/sclm_real_world/gpi_portfolio.csv')
